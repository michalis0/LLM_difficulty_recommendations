# %% [markdown]
# # Cross Validation
#
# The aim of this notebook is to train one or more small-scale models on data from the **Zeeguu** game. We hope to improve the performance obtained with the zero-shot model ([notebooks/topic_classification/b_ZeroShot.ipynb](b_ZeroShot.ipynb)).

# %%
# -------------------------------- PARAMETERS -------------------------------- #
BATCH_SIZE = 8

# %%
# ---------------------------- PREPARING NOTEBOOK ---------------------------- #
# Autoreload
# %load_ext autoreload
# %autoreload 2

# Random seed
import numpy as np
np.random.seed(42)

# External modules
import os
from IPython.display import display, Markdown, Latex, clear_output
from tqdm import notebook as tqdm

# Set global log level
import logging
logging.basicConfig(level=logging.INFO)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Define PWD as the current git repository
import git
repo = git.Repo('.', search_parent_directories=True)
pwd = repo.working_dir
os.chdir(pwd)

# Connect WandB
import wandb
wandb.login()
wandb.init(mode="disabled")
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: henri-jamet. Use `wandb login --relogin` to force relogin

# %%
# ------------------------------- LOAD DATASETS ------------------------------ #
import pandas as pd
from huggingface_hub import snapshot_download


def load_data(sample: int = None, pwd: str = "."):
    # Create fodler
    dataset_path = os.path.join(
        pwd,
        "data",
        "processed",
        "topic_classification",
        "CrossValidation",
    )
    if not os.path.exists(dataset_path):
        os.makedirs(dataset_path)

    # Download CSVs
    snapshot_download(
        repo_id="OloriBern/FLDE",
        allow_patterns=["topic_classification/*.csv"],
        local_dir=dataset_path,
        revision="main",
        repo_type="dataset",
    )

    dataset_path = os.path.join(dataset_path, "topic_classification")

    # Load datasets
    train_df = pd.read_csv(os.path.join(dataset_path, "train.csv"))
    test_df = pd.read_csv(os.path.join(dataset_path, "test.csv"))
    full_df = pd.concat([train_df, test_df])

    # Sample
    train_df = train_df.sample(sample) if sample else train_df
    test_df = test_df.sample(sample) if sample else test_df
    full_df = full_df.sample(sample) if sample else full_df

    return train_df, test_df, full_df


train_dataset, test_df, full_df = load_data(100, pwd)
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# ------------------------------ CREATE DATASET ------------------------------ #
from datasets import Dataset


def create_dataset(df: pd.DataFrame):
    from datasets import Dataset

    dataset = Dataset.from_pandas(df)
    dataset = dataset.rename_column("topic", "label")

    return dataset


train_dataset = create_dataset(train_dataset)
test_dataset = create_dataset(test_df)

# %% [markdown]
# ## Flaubert
#
# First, we will train the same model as the one used for the zero-shot, but this time on Zeeguu data. We will use the Flaubert-base-cased model.

# %%
# -------------------------------- LOAD MODEL -------------------------------- #
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch


def load_model(model_name: str, num_labels: int = 10):
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    # Load model
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name, num_labels=num_labels
    )

    # Move model to GPU
    if torch.cuda.is_available():
        model.to("cuda")

    return tokenizer, model


tokenizer, model = load_model("flaubert/flaubert_base_cased", full_df.topic.nunique())
# Out:
# Some weights of FlaubertForSequenceClassification were not initialized from the model checkpoint at flaubert/flaubert_base_cased and are newly initialized: ['sequence_summary.summary.bias', 'sequence_summary.summary.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----------------------------- TOKENIZE DATASET ----------------------------- #
from sklearn import preprocessing
from datasets import Dataset
from transformers import AutoTokenizer


def tokenize_dataset(dataset: Dataset, tokenizer: AutoTokenizer):
    # Tokenize
    def tokenize(batch):
        return tokenizer(batch["text"], padding="max_length", truncation=True)

    # Encode labels
    label_encoder = preprocessing.LabelEncoder()

    # Apply functions
    dataset = dataset.map(tokenize, batched=True, batch_size=len(dataset))
    dataset = dataset.map(
        lambda examples: {"label": label_encoder.fit_transform(examples["label"])},
        batched=True,
    )
    dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])

    return dataset, label_encoder


train_dataset, label_encoder = tokenize_dataset(train_dataset, tokenizer)
test_dataset, _ = tokenize_dataset(test_dataset, tokenizer)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
# ------------------------------ CREATE TRAINER ------------------------------ #
from transformers import Trainer, TrainingArguments, EarlyStoppingCallback
from datetime import datetime


def create_trainer(
    model,
    train_inputs,
    test_inputs,
    epochs: int = 1,
    batch_size: int = 8,
    pwd: str = ".",
):
    # Create output directory
    output_dir = os.path.join(pwd, "scratch", "topic_classification", "CrossValidation")
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Configure WandB
    os.environ["WANDB_PROJECT"] = "flaubert_topic_classification"

    # Training arguments
    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir=output_dir,
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        run_name=f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}",
        report_to="wandb",
        load_best_model_at_end=True,
    )

    early_stopping = EarlyStoppingCallback(
        early_stopping_patience=3
    )  # Définir le nombre de validation steps avant l'arrêt

    # Create trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_inputs,
        eval_dataset=test_inputs,
        callbacks=[early_stopping],
    )

    return trainer


trainer = create_trainer(
    model, train_dataset, test_dataset, epochs=1, batch_size=BATCH_SIZE, pwd=pwd
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 00:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.344400</td>
#       <td>2.368023</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=13, training_loss=2.3916322267972507, metrics={'train_runtime': 12.0305, 'train_samples_per_second': 8.312, 'train_steps_per_second': 1.081, 'total_flos': 26131801804800.0, 'train_loss': 2.3916322267972507, 'epoch': 1.0})

# %%
# --------------------------- RAY TRAINING FUNCTION -------------------------- #
import ray.train.huggingface.transformers
import dill


def train_model(config):
    # Fix partial import bug
    import ray.train.huggingface
    import ray.train.huggingface.transformers

    # Load arguments
    model_name = config["model_name"]
    epochs = config["epochs"]
    batch_size = config["batch_size"]
    use_ray = config["use_ray"]
    sample = config["sample"]
    pwd = config["pwd"]

    # Load data
    train_dataset, test_df, full_dataset = load_data(sample, pwd)

    # Create dataset
    train_dataset = create_dataset(train_dataset)
    test_dataset = create_dataset(test_df)

    # Load model
    tokenizer, model = load_model(model_name, full_dataset.topic.nunique())

    # Tokenize dataset
    train_dataset, train_label_encoder = tokenize_dataset(train_dataset, tokenizer)
    test_dataset, test_label_encoder = tokenize_dataset(test_dataset, tokenizer)

    # Create trainer
    trainer = create_trainer(
        model,
        train_dataset,
        test_dataset,
        epochs=epochs,
        batch_size=batch_size,
        pwd=pwd,
    )

    if use_ray:
        # Add ray tune callback
        callback = ray.train.huggingface.transformers.RayTrainReportCallback()
        trainer.add_callback(callback)
        trainer = ray.train.huggingface.transformers.prepare_trainer(trainer)

    # Start Training
    trainer.train()

    # Pickle result
    if use_ray:
        with open(os.path.join(pwd, "flaubert_trained.pkl"), "wb") as f:
            dill.dump((model, test_label_encoder), f)

    return model, train_label_encoder, test_label_encoder


model, train_label_encoder, test_label_encoder = train_model(
    {
        "model_name": "flaubert/flaubert_base_cased",
        "epochs": 1,
        "batch_size": BATCH_SIZE,
        "use_ray": False,
        "sample": 100,
        "pwd": pwd,
    }
)
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of FlaubertForSequenceClassification were not initialized from the model checkpoint at flaubert/flaubert_base_cased and are newly initialized: ['sequence_summary.summary.bias', 'sequence_summary.summary.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 00:09, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.595300</td>
#       <td>2.513595</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# ----------------------------- SLURMRAY TRAINING ---------------------------- #
from ray.train import ScalingConfig, CheckpointConfig, RunConfig
from ray.train.torch import TorchTrainer
from slurmray.RayLauncher import RayLauncher


def slurmray_function():
    # Define config
    config = {
        "model_name": "flaubert/flaubert_base_cased",
        "epochs": 20,
        "batch_size": 32,
        "use_ray": True,
        "sample": None,
        "pwd": "/scratch/hjamet",
    }

    # Create ray launcher
    ray_trainer = TorchTrainer(
        train_model,
        scaling_config=ScalingConfig(num_workers=1, use_gpu=True),
        run_config=RunConfig(
            checkpoint_config=CheckpointConfig(
                num_to_keep=1
            ),  # No more needed with the new storage path
            storage_path="/scratch/hjamet",
        ),
        train_loop_config=config,
    )

    # Start training
    result = ray_trainer.fit()

    # Get the result
    with open(os.path.join("/scratch/hjamet", "flaubert_trained.pkl"), "rb") as f:
        model, test_label_encoder = dill.load(f)

    return model, test_label_encoder


# Create ray launcher
launcher = RayLauncher(
    project_name="flaubert-topic-classification",
    func=slurmray_function,
    args={},
    modules=[],
    node_nbr=1,
    use_gpu=True,
    memory=64,
    max_running_time=60,
    server_run=True,
    server_ssh="curnagl.dcsr.unil.ch",
    server_username="hjamet",
)

result = launcher()
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (2.1.1+cu121)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (2.1.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (3.1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (4.8.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (1.12)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (2023.10.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 42)) (3.13.1)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (1.10.13)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (1.20.0)
# Requirement already satisfied: psutil>=5.6.0 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (5.9.6)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 15)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 17)) (0.1.3)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 18)) (4.35.2)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 18)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 18)) (0.23.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 21)) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 21)) (3.0.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 22)) (1.3.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 22)) (2023.10.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 23)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 23)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 24)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 28)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 30)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 32)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 34)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 36)) (0.3.7)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 36)) (1.4.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 37)) (0.4.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 37)) (3.1.40)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 37)) (1.38.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 37)) (58.1.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 37)) (1.3.3)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 38)) (4.1.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 41)) (2.8.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 41)) (0.10.0)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 41)) (3.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 38)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 38)) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 38)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 11)) (2.8.19.14)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 9)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 37)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (2.24.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (6.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (0.12.1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 41)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 41)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 41)) (4.1.1)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 41)) (3.5.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (1.0.7)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (4.20.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (1.59.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (0.7.2)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (2.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (3.0.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 42)) (2.1.3)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (5.5.1)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.12.0)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.27.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.0.6)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 13)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 18)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 41)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 37)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 24)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 41)) (7.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (25.1.2)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.18.1)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.5.8)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 41)) (0.13.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 14)) (3.0.41)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (5.9.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (4.12.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.11.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.25.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 41)) (2.21)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.4.4)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.18.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (7.4.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 30)) (3.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (21.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1801-16h42.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1801-16h42_queue.log>
# Submitted batch job 37138979
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2024-01-18 16:42:22,625	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-18 16:42:22,625	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2024-01-18 16:42:27,461	SUCC scripts.py:781 -- --------------------
# 2024-01-18 16:42:27,461	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-18 16:42:27,461	SUCC scripts.py:783 -- --------------------
# 2024-01-18 16:42:27,461	INFO scripts.py:785 -- Next steps
# 2024-01-18 16:42:27,461	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-18 16:42:27,461	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2024-01-18 16:42:27,461	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-18 16:42:27,461	INFO scripts.py:802 -- import ray
# 2024-01-18 16:42:27,461	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2024-01-18 16:42:27,461	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-18 16:42:27,461	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-18 16:42:27,461	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-18 16:42:27,462	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-18 16:42:27,462	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-18 16:42:27,462	INFO scripts.py:835 --   ray stop
# 2024-01-18 16:42:27,462	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-18 16:42:27,462	INFO scripts.py:839 --   ray status
# 2024-01-18 16:42:27,462	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-18 16:42:27,462	INFO scripts.py:844 --   10.203.101.82:8265
# 2024-01-18 16:42:27,462	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-18 16:42:27,462	INFO scripts.py:952 -- --block
# 2024-01-18 16:42:27,462	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-18 16:42:27,462	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-18 16:42:51,141	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2024-01-18 16:42:51,155	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
# 2024-01-18 16:43:32,629	INFO tune.py:595 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (TrainTrainable pid=2971311) /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# (TrainTrainable pid=2971311)   warn("The installed version of bitsandbytes was compiled without GPU support. "
# (TorchTrainer pid=2971311) Starting distributed worker processes: ['2971367 (10.203.101.82)']
# (RayTrainWorker pid=2971367) Setting up process group for: env:// [rank=0, world_size=1]
# (RayTrainWorker pid=2971367)
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# (RayTrainWorker pid=2971367)
# Fetching 2 files:  50%|█████     | 1/2 [00:00<00:00,  7.74it/s]
# (RayTrainWorker pid=2971367)
# Fetching 2 files: 100%|██████████| 2/2 [00:00<00:00, 14.16it/s]
# (RayTrainWorker pid=2971367) Some weights of FlaubertForSequenceClassification were not initialized from the model checkpoint at flaubert/flaubert_base_cased and are newly initialized: ['sequence_summary.summary.weight', 'sequence_summary.summary.bias']
# (RayTrainWorker pid=2971367) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (RayTrainWorker pid=2971367)
# Map:   0%|          | 0/7801 [00:00<?, ? examples/s]
# (RayTrainWorker pid=2971367)
# Map: 100%|██████████| 7801/7801 [03:11<00:00, 40.78 examples/s]
# (RayTrainWorker pid=2971367)
# Map: 100%|██████████| 7801/7801 [03:11<00:00, 40.77 examples/s]
# (RayTrainWorker pid=2971367)
# Map:   0%|          | 0/7801 [00:00<?, ? examples/s]
# Map: 100%|██████████| 7801/7801 [00:00<00:00, 173021.58 examples/s]
# (RayTrainWorker pid=2971367)
# Map:   0%|          | 0/1951 [00:00<?, ? examples/s]
# (RayTrainWorker pid=2971367)
# Map: 100%|██████████| 1951/1951 [00:47<00:00, 40.74 examples/s]
# Map: 100%|██████████| 1951/1951 [00:47<00:00, 40.73 examples/s]
# (RayTrainWorker pid=2971367)
# Map:   0%|          | 0/1951 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1951/1951 [00:00<00:00, 123976.78 examples/s]
# (RayTrainWorker pid=2971367) wandb: Currently logged in as: henri-jamet. Use `wandb login --relogin` to force relogin
# (RayTrainWorker pid=2971367) wandb: wandb version 0.16.2 is available!  To upgrade, please run:
# (RayTrainWorker pid=2971367) wandb:  $ pip install wandb --upgrade
# (RayTrainWorker pid=2971367) wandb: Tracking run with wandb version 0.16.0
# (RayTrainWorker pid=2971367) wandb: Run data is saved locally in /users/hjamet/ray_results/TorchTrainer_2024-01-18_16-43-32/TorchTrainer_55951_00000_0_2024-01-18_16-43-32/wandb/run-20240118_164801-vhb8g8gu
# (RayTrainWorker pid=2971367) wandb: Run `wandb offline` to turn off syncing.
# (RayTrainWorker pid=2971367) wandb: Syncing run 2024-01-18_16-47-58
# (RayTrainWorker pid=2971367) wandb: ⭐️ View project at https://wandb.ai/henri-jamet/flaubert_topic_classification
# (RayTrainWorker pid=2971367) wandb: 🚀 View run at https://wandb.ai/henri-jamet/flaubert_topic_classification/runs/vhb8g8gu
# (RayTrainWorker pid=2971367)
#   0%|          | 0/4880 [00:00<?, ?it/s]
# (RayTrainWorker pid=2971367) [W reducer.cpp:1346] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# (RayTrainWorker pid=2971367)
#   0%|          | 1/4880 [00:01<1:53:56,  1.40s/it]
# (RayTrainWorker pid=2971367)
#   0%|          | 2/4880 [00:02<1:21:27,  1.00s/it]
# (RayTrainWorker pid=2971367)
#   0%|          | 3/4880 [00:02<1:11:20,  1.14it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 4/4880 [00:03<1:06:31,  1.22it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 5/4880 [00:04<1:03:49,  1.27it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 6/4880 [00:05<1:02:05,  1.31it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 7/4880 [00:05<1:00:58,  1.33it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 8/4880 [00:06<1:00:16,  1.35it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 9/4880 [00:07<59:49,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 10/4880 [00:07<59:25,  1.37it/s]
#
#
#   0%|          | 10/4880 [00:07<59:25,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 11/4880 [00:08<59:40,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 12/4880 [00:09<59:27,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 13/4880 [00:10<59:19,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 14/4880 [00:10<59:20,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 15/4880 [00:11<59:09,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 16/4880 [00:12<59:06,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 17/4880 [00:13<59:01,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 18/4880 [00:13<58:55,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 19/4880 [00:14<58:55,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 20/4880 [00:15<58:49,  1.38it/s]
#
#
#   0%|          | 20/4880 [00:15<58:49,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 21/4880 [00:15<58:48,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 22/4880 [00:16<58:45,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 23/4880 [00:17<58:45,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 24/4880 [00:18<58:47,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 25/4880 [00:18<58:45,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 26/4880 [00:19<58:45,  1.38it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 27/4880 [00:20<58:49,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 28/4880 [00:21<58:49,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 29/4880 [00:21<58:50,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 30/4880 [00:22<58:51,  1.37it/s]
#
#
#   1%|          | 30/4880 [00:22<58:51,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 31/4880 [00:23<1:01:49,  1.31it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 32/4880 [00:24<1:00:59,  1.32it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 33/4880 [00:24<1:00:16,  1.34it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 34/4880 [00:25<59:54,  1.35it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 35/4880 [00:26<59:30,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 36/4880 [00:26<59:18,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 37/4880 [00:27<59:09,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 38/4880 [00:28<58:58,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 39/4880 [00:29<58:53,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 40/4880 [00:29<59:06,  1.36it/s]
#
#
#   1%|          | 40/4880 [00:29<59:06,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 41/4880 [00:30<59:13,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 42/4880 [00:31<1:01:05,  1.32it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 43/4880 [00:32<1:00:20,  1.34it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 44/4880 [00:32<59:52,  1.35it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 45/4880 [00:33<59:29,  1.35it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 46/4880 [00:34<59:16,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 47/4880 [00:35<59:05,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 48/4880 [00:35<58:59,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 49/4880 [00:36<59:00,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 50/4880 [00:37<58:51,  1.37it/s]
#
#
#   1%|          | 50/4880 [00:37<58:51,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 51/4880 [00:38<58:58,  1.36it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 52/4880 [00:38<58:52,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 53/4880 [00:39<58:46,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 54/4880 [00:40<58:45,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 55/4880 [00:40<58:41,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 56/4880 [00:41<58:41,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 57/4880 [00:42<58:45,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 58/4880 [00:43<58:39,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 59/4880 [00:43<58:37,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|          | 60/4880 [00:44<58:43,  1.37it/s]
#
#
#   1%|          | 60/4880 [00:44<58:43,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|▏         | 61/4880 [00:45<58:36,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|▏         | 62/4880 [00:46<58:40,  1.37it/s]
# (RayTrainWorker pid=2971367)
#   1%|▏         | 63/4880 [00:46<58:37,  1.37it/s]
# (RayTrainWorker pid=2971367)
# ...
#  33%|███▎      | 1626/4880 [22:08<40:33,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1627/4880 [22:08<40:23,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1628/4880 [22:09<40:21,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1629/4880 [22:10<40:18,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1630/4880 [22:11<40:14,  1.35it/s]
#
#
#  33%|███▎      | 1630/4880 [22:11<40:14,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1631/4880 [22:11<40:11,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1632/4880 [22:12<40:07,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1633/4880 [22:13<40:02,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 1634/4880 [22:13<40:00,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1635/4880 [22:14<41:29,  1.30it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1636/4880 [22:15<41:34,  1.30it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1637/4880 [22:16<41:07,  1.31it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1638/4880 [22:17<40:47,  1.32it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1639/4880 [22:17<42:10,  1.28it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1640/4880 [22:18<41:28,  1.30it/s]
#
#
#  34%|███▎      | 1640/4880 [22:18<41:28,  1.30it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1641/4880 [22:19<41:02,  1.32it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1642/4880 [22:20<40:40,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1643/4880 [22:20<40:27,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1644/4880 [22:21<40:14,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1645/4880 [22:22<40:06,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▎      | 1646/4880 [22:23<39:59,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1647/4880 [22:23<39:59,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1648/4880 [22:24<39:54,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1649/4880 [22:25<39:53,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1650/4880 [22:26<39:50,  1.35it/s]
#
#
#  34%|███▍      | 1650/4880 [22:26<39:50,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1651/4880 [22:26<39:53,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1652/4880 [22:27<39:48,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1653/4880 [22:28<39:44,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1654/4880 [22:29<39:45,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1655/4880 [22:29<41:31,  1.29it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1656/4880 [22:30<41:06,  1.31it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1657/4880 [22:31<40:36,  1.32it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1658/4880 [22:32<40:17,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1659/4880 [22:32<40:10,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1660/4880 [22:33<40:07,  1.34it/s]
#
#
#  34%|███▍      | 1660/4880 [22:33<40:07,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1661/4880 [22:34<40:23,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1662/4880 [22:35<40:50,  1.31it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1663/4880 [22:35<40:25,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1664/4880 [22:36<40:09,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1665/4880 [22:37<39:56,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1666/4880 [22:38<39:59,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1667/4880 [22:38<39:46,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1668/4880 [22:39<39:43,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1669/4880 [22:40<39:40,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1670/4880 [22:41<39:37,  1.35it/s]
#
#
#  34%|███▍      | 1670/4880 [22:41<39:37,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1671/4880 [22:41<39:40,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1672/4880 [22:42<39:37,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1673/4880 [22:43<39:34,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1674/4880 [22:43<39:31,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1675/4880 [22:44<39:31,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1676/4880 [22:45<39:34,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1677/4880 [22:46<41:35,  1.28it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1678/4880 [22:47<41:05,  1.30it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1679/4880 [22:47<40:34,  1.31it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1680/4880 [22:48<40:17,  1.32it/s]
#
#
#  34%|███▍      | 1680/4880 [22:48<40:17,  1.32it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1681/4880 [22:49<40:02,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1682/4880 [22:50<40:00,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 1683/4880 [22:50<39:49,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1684/4880 [22:51<39:43,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1685/4880 [22:52<40:11,  1.32it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1686/4880 [22:53<39:54,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1687/4880 [22:53<39:42,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1688/4880 [22:54<39:35,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1689/4880 [22:55<39:29,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1690/4880 [22:56<39:40,  1.34it/s]
#
#
#  35%|███▍      | 1690/4880 [22:56<39:40,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1691/4880 [22:56<39:34,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1692/4880 [22:57<39:31,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1693/4880 [22:58<39:27,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1694/4880 [22:58<39:23,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1695/4880 [22:59<39:20,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1696/4880 [23:00<39:32,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1697/4880 [23:01<39:23,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1698/4880 [23:01<39:22,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1699/4880 [23:02<39:18,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1700/4880 [23:03<39:16,  1.35it/s]
#
#
#  35%|███▍      | 1700/4880 [23:03<39:16,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1701/4880 [23:04<39:41,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1702/4880 [23:04<39:44,  1.33it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1703/4880 [23:05<39:34,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1704/4880 [23:06<39:36,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1705/4880 [23:07<39:37,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1706/4880 [23:07<39:24,  1.34it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▍      | 1707/4880 [23:08<39:15,  1.35it/s]
# (RayTrainWorker pid=2971367)
#  35%|███▌      | 1708/4880 [23:09<37:41,  1.40it/s]
# (RayTrainWorker pid=2971367)
#   0%|          | 0/61 [00:00<?, ?it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#   3%|▎         | 2/61 [00:00<00:06,  8.83it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#   5%|▍         | 3/61 [00:00<00:09,  6.18it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#   7%|▋         | 4/61 [00:00<00:11,  5.06it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#   8%|▊         | 5/61 [00:00<00:11,  4.97it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  10%|▉         | 6/61 [00:01<00:11,  4.62it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  11%|█▏        | 7/61 [00:01<00:11,  4.53it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  13%|█▎        | 8/61 [00:01<00:11,  4.50it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  15%|█▍        | 9/61 [00:01<00:11,  4.45it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  16%|█▋        | 10/61 [00:02<00:11,  4.42it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  18%|█▊        | 11/61 [00:02<00:11,  4.36it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  20%|█▉        | 12/61 [00:02<00:11,  4.38it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  21%|██▏       | 13/61 [00:02<00:11,  4.11it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  23%|██▎       | 14/61 [00:03<00:11,  4.11it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  25%|██▍       | 15/61 [00:03<00:10,  4.19it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  26%|██▌       | 16/61 [00:03<00:10,  4.23it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  28%|██▊       | 17/61 [00:03<00:10,  4.26it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  30%|██▉       | 18/61 [00:03<00:10,  4.29it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  31%|███       | 19/61 [00:04<00:09,  4.30it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  33%|███▎      | 20/61 [00:04<00:09,  4.30it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  34%|███▍      | 21/61 [00:04<00:09,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  36%|███▌      | 22/61 [00:04<00:09,  4.33it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  38%|███▊      | 23/61 [00:05<00:08,  4.33it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  39%|███▉      | 24/61 [00:05<00:08,  4.33it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  41%|████      | 25/61 [00:05<00:09,  3.66it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  43%|████▎     | 26/61 [00:05<00:09,  3.86it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  44%|████▍     | 27/61 [00:06<00:08,  4.00it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  46%|████▌     | 28/61 [00:06<00:08,  4.11it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  48%|████▊     | 29/61 [00:06<00:07,  4.18it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  49%|████▉     | 30/61 [00:06<00:07,  4.23it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  51%|█████     | 31/61 [00:07<00:07,  4.24it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  52%|█████▏    | 32/61 [00:07<00:06,  4.27it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  54%|█████▍    | 33/61 [00:07<00:06,  4.30it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  56%|█████▌    | 34/61 [00:07<00:06,  4.31it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  57%|█████▋    | 35/61 [00:08<00:06,  4.31it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  59%|█████▉    | 36/61 [00:08<00:05,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  61%|██████    | 37/61 [00:08<00:06,  3.86it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  62%|██████▏   | 38/61 [00:08<00:05,  3.94it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  64%|██████▍   | 39/61 [00:09<00:05,  4.07it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  66%|██████▌   | 40/61 [00:09<00:05,  4.14it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  67%|██████▋   | 41/61 [00:09<00:04,  4.21it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  69%|██████▉   | 42/61 [00:09<00:04,  4.23it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  70%|███████   | 43/61 [00:09<00:04,  4.27it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  72%|███████▏  | 44/61 [00:10<00:03,  4.29it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  74%|███████▍  | 45/61 [00:10<00:03,  4.29it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  75%|███████▌  | 46/61 [00:10<00:03,  4.31it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  77%|███████▋  | 47/61 [00:10<00:03,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  79%|███████▊  | 48/61 [00:11<00:03,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  80%|████████  | 49/61 [00:11<00:03,  3.80it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  82%|████████▏ | 50/61 [00:11<00:02,  3.86it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  84%|████████▎ | 51/61 [00:11<00:02,  3.98it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  85%|████████▌ | 52/61 [00:12<00:02,  4.10it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  87%|████████▋ | 53/61 [00:12<00:01,  4.16it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  89%|████████▊ | 54/61 [00:12<00:01,  4.20it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  90%|█████████ | 55/61 [00:12<00:01,  4.25it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  92%|█████████▏| 56/61 [00:13<00:01,  4.28it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  93%|█████████▎| 57/61 [00:13<00:00,  4.28it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  95%|█████████▌| 58/61 [00:13<00:00,  4.30it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  97%|█████████▋| 59/61 [00:13<00:00,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
#  98%|█████████▊| 60/61 [00:14<00:00,  4.32it/s]
# (RayTrainWorker pid=2971367)
# (RayTrainWorker pid=2971367)
# 100%|██████████| 61/61 [00:14<00:00,  3.81it/s]
# (RayTrainWorker pid=2971367)
#
# (RayTrainWorker pid=2971367)
#
#
#  35%|███▌      | 1708/4880 [23:23<37:41,  1.40it/s]
# (RayTrainWorker pid=2971367)
# 100%|██████████| 61/61 [00:14<00:00,  3.81it/s]
# (RayTrainWorker pid=2971367)
#
# (RayTrainWorker pid=2971367) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/scratch/hjamet/TorchTrainer_2024-01-18_16-43-32/TorchTrainer_55951_00000_0_2024-01-18_16-43-32/checkpoint_000006)
# (RayTrainWorker pid=2971367)
#
#
#  35%|███▌      | 1708/4880 [23:31<37:41,  1.40it/s]
#  35%|███▌      | 1708/4880 [23:31<43:41,  1.21it/s]
# 2024-01-18 17:11:36,982	WARNING experiment_state.py:327 -- Experiment checkpoint syncing has been triggered multiple times in the last 30.0 seconds. A sync will be triggered whenever a trial has checkpointed more than `num_to_keep` times since last sync or if 300 seconds have passed since last sync. If you have set `num_to_keep` in your `CheckpointConfig`, consider increasing the checkpoint frequency or keeping more checkpoints. You can supress this warning by changing the `TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S` environment variable.
# Job finished!
# Downloading result...
# Result downloaded!
# /home/lopilo24/UNIL/Lingo_other_branch/Lingorank_LLM/.venv/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# -------------------------------- SAVE RESULT ------------------------------- #
model, test_label_encoder = result

model.save_pretrained(
    os.path.join(
        pwd, "scratch", "topic_classification", "CrossValidation", "flaubert_fine_tuned"
    )
)
with open(
    os.path.join(
        pwd,
        "scratch",
        "topic_classification",
        "CrossValidation",
        "flaubert_fine_tuned_label_encoder.pkl",
    ),
    "wb",
) as f:
    dill.dump(test_label_encoder, f)

# %%
# --------------------------- COMPUTING PREDICTIONS -------------------------- #
from torch.utils.data import DataLoader
from datasets import Dataset

# Load model, tokenizer and label encoder
model = AutoModelForSequenceClassification.from_pretrained(
    os.path.join(
        pwd, "scratch", "topic_classification", "CrossValidation", "flaubert_fine_tuned"
    )
).cuda()
tokenizer = AutoTokenizer.from_pretrained("flaubert/flaubert_base_cased")
label_encoder = dill.load(
    open(
        os.path.join(
            pwd,
            "scratch",
            "topic_classification",
            "CrossValidation",
            "flaubert_fine_tuned_label_encoder.pkl",
        ),
        "rb",
    )
)

# Load test dataset
_, test_df, _ = load_data(None, pwd)
test_dataset = create_dataset(test_df)
test_dataset, _ = tokenize_dataset(test_dataset, tokenizer)
test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Compute predictions
predictions = {"labels": [], "scores": []}
for batch in tqdm.tqdm(test_dataloader):
    with torch.no_grad():
        model.eval()
        outputs = model(
            input_ids=batch["input_ids"].cuda(),
            attention_mask=batch["attention_mask"].cuda(),
            labels=batch["label"].cuda(),
        )
        labels = label_encoder.classes_
        scores = torch.softmax(outputs.logits, dim=1).cpu().numpy()
        # Sort labels by score
        labels = np.array(labels)[np.argsort(-scores, axis=1)]
        scores = -np.sort(-scores, axis=1)
        predictions["labels"].extend(labels)
        predictions["scores"].extend(scores)
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Map:   0%|          | 0/1951 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1951 [00:00<?, ? examples/s]
#   0%|          | 0/244 [00:00<?, ?it/s]

# %%
# Create results dataframe
result = pd.DataFrame(predictions)
result["label"] = label_encoder.inverse_transform(test_dataset["label"])

# Save results
path = os.path.join(
    pwd,
    "results",
    "topic_classification",
    "FlaubertFineTuned",
    "flaubert_fine_tuned_predictions.csv",
)
## Create folder if it does not exist
os.makedirs(os.path.dirname(path), exist_ok=True)
result.to_csv(path, index=False)

result
# Out:
#                                                  labels  \
# 0     [Sport, Culture, World, Science, Music, Techno...
# 1     [Sport, Technology, Health, Culture, Business,...
# 2     [Sport, Health, Culture, Science, Technology, ...
# 3     [World, Science, Health, Politics, Business, S...
# 4     [Music, Culture, Health, Travel, Sport, Scienc...
# ...                                                 ...
# 1946  [Culture, World, Science, Travel, Health, Musi...
# 1947  [Culture, Travel, Health, World, Music, Food, ...
# 1948  [Sport, Culture, Politics, Science, Health, Tr...
# 1949  [Culture, Travel, Health, Science, Politics, M...
# 1950  [Travel, Science, Culture, Health, World, Spor...
#
#                                                  scores    label
# 0     [0.7932583, 0.14117028, 0.019363042, 0.0121266...  Science
# 1     [0.9972519, 0.0006286009, 0.00060514075, 0.000...    Sport
# 2     [0.9727734, 0.019157162, 0.0024887489, 0.00204...    Sport
# 3     [0.9765069, 0.0140596535, 0.0047480706, 0.0018...    World
# 4     [0.8318409, 0.15282308, 0.005733552, 0.0023423...    Music
# ...                                                 ...      ...
# 1946  [0.9605047, 0.01461302, 0.012548375, 0.0067454...  Culture
# 1947  [0.49946365, 0.4749205, 0.0060213213, 0.005922...  Culture
# 1948  [0.8961946, 0.03308948, 0.015245182, 0.0147003...  Culture
# 1949  [0.94756174, 0.019440182, 0.009956354, 0.00701...  Culture
# 1950  [0.8367814, 0.049699172, 0.033928014, 0.031523...   Travel
#
# [1951 rows x 3 columns]

# %%
import pandas as pd

# Load results
path = os.path.join(
    pwd,
    "results",
    "topic_classification",
    "FlaubertFineTuned",
    "flaubert_fine_tuned_predictions.csv",
)
result = pd.read_csv(path)
result["labels"] = result["labels"].apply(eval)
result["scores"] = result["scores"].apply(eval)


def is_in_top_n(label: str, n: int = 1):
    return result[result["label"] == label]["labels"].apply(lambda x: label in x[:n])


metrics = {}
for label in result["label"].unique():
    metrics[label] = {
        "accuracy@1": is_in_top_n(label, 1).mean(),
        "accuracy@3": is_in_top_n(label, 3).mean(),
        "accuracy@5": is_in_top_n(label, 5).mean(),
    }
metrics["Average"] = {
    "accuracy@1": result.apply(lambda x: x["label"] in x["labels"][:1], axis=1).mean(),
    "accuracy@3": result.apply(lambda x: x["label"] in x["labels"][:3], axis=1).mean(),
    "accuracy@5": result.apply(lambda x: x["label"] in x["labels"][:5], axis=1).mean(),
}

metrics = pd.DataFrame(metrics).T
metrics = metrics.sort_values("accuracy@1", ascending=True)

# Move Average row to the top
metrics = pd.concat([metrics.drop("Average"), metrics.loc[["Average"]]])

# Save metrics
path = os.path.join(
    pwd,
    "results",
    "topic_classification",
    "FlaubertFineTuned",
    "flaubert_fine_tuned_metrics.csv",
)
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
metrics.to_csv(path)

display(metrics)

# Calculate precision, recall and f1-score
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(
    result["label"].tolist(),
    result["labels"].apply(lambda x: x[0]).tolist(),
    average="micro",
)
recall = recall_score(
    result["label"].tolist(),
    result["labels"].apply(lambda x: x[0]).tolist(),
    average="micro",
)
f1 = f1_score(
    result["label"].tolist(),
    result["labels"].apply(lambda x: x[0]).tolist(),
    average="micro",
)
classification_metrics = pd.DataFrame(
    {
        "accuracy": [metrics.loc["Average", "accuracy@1"]],
        "precision": [precision],
        "recall": [recall],
        "f1": [f1],
    },
    index=["FlaubertFineTuned"],
)

# Save metrics
path = os.path.join(
    pwd,
    "results",
    "topic_classification",
    "FlaubertFineTuned",
    "flaubert_fine_tuned_classification_metrics.csv",
)
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
classification_metrics.to_csv(path)

display(classification_metrics)

import matplotlib.pyplot as plt
import seaborn as sns

# Assurez-vous que le DataFrame 'metrics' est déjà créé et trié par 'accuracy@1'
# metrics.sort_values("accuracy@1", ascending=False)

# Réinitialiser l'index pour pouvoir utiliser la colonne des labels dans le graphique
metrics.reset_index(inplace=True)
metrics.rename(columns={"index": "Label"}, inplace=True)

# Nous utilisons seaborn pour un style de graphique amélioré
sns.set_theme(style="whitegrid")

# La taille du graphique peut être ajustée pour mieux s'adapter à vos données
plt.figure(figsize=(10, 8))

# Création d'un graphique à barres empilées
# bottom paramètre spécifie où la barre commence, donc nous empilons en additionnant la précision précédente
plt.barh(metrics["Label"], metrics["accuracy@1"], label="Top 1 Accuracy", height=0.6)
plt.barh(
    metrics["Label"],
    metrics["accuracy@3"] - metrics["accuracy@1"],
    label="Top 3 Accuracy",
    height=0.5,
    left=metrics["accuracy@1"],
)
plt.barh(
    metrics["Label"],
    metrics["accuracy@5"] - metrics["accuracy@3"],
    label="Top 5 Accuracy",
    height=0.4,
    left=metrics["accuracy@3"],
)

# Titre du graphique et étiquettes des axes
plt.title("Accuracies at Top N")
plt.xlabel("Accuracy")
plt.ylabel("Label")

# Rotation des étiquettes sur l'axe des x pour une meilleure lisibilité si nécessaire
plt.xticks(rotation=45, ha="right")

# Ajout d'une légende
plt.legend()

# Utilisez plt.tight_layout() si vous constatez que les étiquettes sont coupées dans la sortie finale
plt.tight_layout()

# Remove grid
plt.grid(False)

# Give specific color to first bar
plt.gca().get_children()[11].set(
    color="#1f77b4", alpha=0.8, edgecolor="black", height=1
)
plt.gca().get_children()[23].set(
    color="#ff7f0e", alpha=0.8, edgecolor="black", height=0.9
)
plt.gca().get_children()[35].set(
    color="#2ca02c", alpha=0.8, edgecolor="black", height=0.8
)

# Affichage du graphique
plt.show()
# Out:
#             accuracy@1  accuracy@3  accuracy@5
# Science       0.453901    0.964539    1.000000
# Business      0.535714    0.785714    0.785714
# Food          0.714286    0.880952    0.880952
# Politics      0.745902    0.909836    0.967213
# Culture       0.749129    0.965157    0.996516
# Travel        0.796954    0.974619    0.994924
# Music         0.802721    0.945578    0.993197
# Health        0.809735    0.986726    0.995575
# World         0.814516    0.991935    1.000000
# Technology    0.835443    0.962025    0.974684
# Sport         0.903226    0.974910    0.996416
# Average       0.791389    0.963608    0.988211
#                    accuracy  precision    recall        f1
# FlaubertFineTuned  0.791389   0.791389  0.791389  0.791389
