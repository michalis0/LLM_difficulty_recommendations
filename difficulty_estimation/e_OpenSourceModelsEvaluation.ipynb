# %% [markdown]
# # Evaluation of Open-Source models
#
# The aim of this notebook is to generate predictions for the Open-Source models trained in the previous notebook (`OpenSourceModelTraining.ipynb`).

# %%
# ---------------------------- PREPARING NOTEBOOK ---------------------------- #
# Autoreload
# %load_ext autoreload
# %autoreload 2

# Random seed
import numpy as np
np.random.seed(42)

# External modules
import os
from IPython.display import display, Markdown, Latex, clear_output
from tqdm import notebook as tqdm

# Set global log level
import logging
logging.basicConfig(level=logging.INFO)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Define PWD as the current git repository
import git
repo = git.Repo('.', search_parent_directories=True)
pwd = repo.working_dir
os.chdir(pwd)

# %%
# --------------------------- LOAD AND PREPARE DATA -------------------------- #
import os
import pandas as pd

csv_list = {}
for file in os.listdir(os.path.join(pwd, "data", "raw", "difficulty_estimation")):
    if file.endswith(".csv"):
        file_key = [
            "_".join(os.path.splitext(file)[0].split("_")[:-1]),
            os.path.splitext(file)[0].split("_")[-1],
        ]
        if file_key[0] not in csv_list:
            csv_list[file_key[0]] = {}
        csv_list[file_key[0]][file_key[1]] = pd.read_csv(
            os.path.join(pwd, "data", "raw", "difficulty_estimation", file)
        )

# %% [markdown]
# ## Bert
#
# First, we will generate the predictions of the **Bert** model.

# %%
# ---------------------------- COMPUTE PREDICTIONS --------------------------- #=
def bert_predict(dataset: str, huggingface_token: str):
    import dill
    import torch
    from transformers import CamembertForSequenceClassification
    from huggingface_hub import snapshot_download, login

    # Set huggingface token
    login(token=huggingface_token)

    # Clone model checkpoint
    snapshot_download(
        repo_id=f"OloriBern/Lingorank_Bert_{dataset}",
        local_dir=dataset,
        revision="main",
        repo_type="model",
    )

    # Load tokenizer and label encoder
    with open(
        os.path.join(
            dataset,
            "train_camembert_tokenizer_label_encoder.pkl",
        ),
        "rb",
    ) as f:
        tokenizer, label_encoder = dill.load(f)

    # Charger le modèle; assurons-nous qu'il matche la classe de votre modèle
    model = CamembertForSequenceClassification.from_pretrained(dataset)

    # Mettre le modèle en mode évaluation
    model.eval()

    # Préparer les données pour le modèle
    inputs = tokenizer(
        csv_list[dataset]["test"]["sentence"].tolist(),
        padding=True,
        truncation=True,
        return_tensors="pt",
    )

    # Charger les tensors sur l'appareil adéquat (GPU si disponible)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    # Désactiver le calcul du gradient puisque nous sommes en inférence
    with torch.no_grad():
        # Faire les prédictions
        outputs = model(**inputs)

    # Appliquer une fonction softmax pour obtenir les probabilités
    predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)

    # Convertir les prédictions en numpy array pour faciliter l'accès aux résultats et leur manipulation
    predictions = predictions.cpu().numpy()

    # Get best predictions
    predictions = np.argmax(predictions, axis=1)

    # Apply label encoder
    predictions = label_encoder.inverse_transform(predictions)

    return predictions

# %%
# -------------------------- CONNECT TO HUGGINGFACE -------------------------- #
from getpass import getpass
from huggingface_hub import login
import os

connected = False
while not (connected):
    try:
        with open(os.path.join(pwd, ".huggingface_key"), "r") as f:
            huggingface_token = f.read()
            login(token=huggingface_token)
            connected = True
    except:
        huggingface_token = getpass("Enter your HuggingFace token: ")
        with open(os.path.join(pwd, ".huggingface_key"), "w") as f:
            f.write(huggingface_token)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/lopilo24/.cache/huggingface/token
# Login successful

# %%
# ------------------------- DEFINE SLURMRAY LAUNCHER ------------------------- #
from slurmray.RayLauncher import RayLauncher

create_launcher = lambda dataset: RayLauncher(
    project_name="camembert_base_difficulty_estimation",
    func=bert_predict,
    args={
        "dataset": dataset,
        "huggingface_token": huggingface_token,
    },
    modules=[],
    node_nbr=1,
    use_gpu=True,
    memory=128,
    max_running_time=60,
    server_run=True,
    server_ssh="curnagl.dcsr.unil.ch",
    server_username="hjamet",
)

# %%
# ---------------------- ...AND COMPUTE LJL PREDICTIONS ---------------------- #
ljl_predictions = create_launcher("ljl")()
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (2.0.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.15.2)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (3.5.0)
# Requirement already satisfied: torch==2.0.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (2.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.4.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.2.10.91)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.2.1)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.4.0.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.14.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (1.12)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (4.8.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.101)
# Requirement already satisfied: triton==2.0.0 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.0.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (8.5.0.96)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.91)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.13.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.1.2)
# Requirement already satisfied: wheel in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (0.42.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (58.1.0)
# Requirement already satisfied: lit in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (17.0.6)
# Requirement already satisfied: cmake in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (3.27.9)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2023.10.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.70.15)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.16.4)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (14.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (1.26.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (1.10.13)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (1.20.0)
# Requirement already satisfied: psutil>=5.6.0 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (5.9.6)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 16)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (0.1.3)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.23.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (2.17.2)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (2023.10.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 25)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 29)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 31)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 33)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 35)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (0.3.7)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.38.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (3.1.40)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (0.4.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.3.3)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 39)) (4.1.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (2.8.1)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (0.10.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 11)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 9)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (2.24.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 22)) (0.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (4.46.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (4.1.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (3.5.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.0.7)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (4.20.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.59.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (2.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (0.7.2)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.0.1->-r requirements.txt (line 43)) (2.1.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.27.1)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (5.5.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.0.6)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.12.0)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 13)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.0.1->-r requirements.txt (line 43)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 19)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (7.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.18.1)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (6.4)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (25.1.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.6.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.5.8)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.13.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 14)) (3.0.41)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (5.9.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.11.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (2.21)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.4.4)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (7.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: tomli in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.8.3)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (21.2.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h48.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h48_queue.log>
# Submitted batch job 35880823
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2023-12-12 18:48:50,491	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2023-12-12 18:48:50,491	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2023-12-12 18:48:55,318	SUCC scripts.py:781 -- --------------------
# 2023-12-12 18:48:55,318	SUCC scripts.py:782 -- Ray runtime started.
# 2023-12-12 18:48:55,318	SUCC scripts.py:783 -- --------------------
# 2023-12-12 18:48:55,318	INFO scripts.py:785 -- Next steps
# 2023-12-12 18:48:55,318	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2023-12-12 18:48:55,318	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2023-12-12 18:48:55,318	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2023-12-12 18:48:55,318	INFO scripts.py:802 -- import ray
# 2023-12-12 18:48:55,318	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2023-12-12 18:48:55,318	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2023-12-12 18:48:55,318	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2023-12-12 18:48:55,318	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2023-12-12 18:48:55,318	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2023-12-12 18:48:55,318	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2023-12-12 18:48:55,318	INFO scripts.py:835 --   ray stop
# 2023-12-12 18:48:55,318	INFO scripts.py:838 -- To view the status of the cluster, use
# 2023-12-12 18:48:55,318	INFO scripts.py:839 --   ray status
# 2023-12-12 18:48:55,318	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2023-12-12 18:48:55,319	INFO scripts.py:844 --   10.203.101.82:8265
# 2023-12-12 18:48:55,319	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2023-12-12 18:48:55,319	INFO scripts.py:952 -- --block
# 2023-12-12 18:48:55,319	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2023-12-12 18:48:55,319	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2023-12-12 18:49:19,197	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2023-12-12 18:49:19,210	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /users/hjamet/.cache/huggingface/token
# Login successful
#
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Fetching 10 files:  10%|█         | 1/10 [00:00<00:01,  5.66it/s]
# Fetching 10 files:  90%|█████████ | 9/10 [00:00<00:00, 33.49it/s]
# Fetching 10 files: 100%|██████████| 10/10 [00:00<00:00, 30.08it/s]
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------- ...AND COMPUTE SENTENCES PREDICTIONS ------------------- #
sentences_predictions = create_launcher("sentences")()
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (2.0.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.15.2)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (3.5.0)
# Requirement already satisfied: torch==2.0.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (2.0.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.14.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.1.2)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.4.0.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (1.12)
# Requirement already satisfied: triton==2.0.0 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.0.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.4.91)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.2.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.9.0.58)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (4.8.0)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.2.10.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.91)
# Requirement already satisfied: wheel in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (0.42.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (58.1.0)
# Requirement already satisfied: lit in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (17.0.6)
# Requirement already satisfied: cmake in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (3.27.9)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.70.15)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (4.66.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (1.26.2)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (14.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2023.10.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.16.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (1.10.13)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (1.20.0)
# Requirement already satisfied: psutil>=5.6.0 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (5.9.6)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 16)) (4.21.12)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (2.14.0)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.23.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (4.35.2)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (2.17.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (2023.10.3)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (1.11.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 25)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 29)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 31)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 33)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 35)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (0.3.7)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (1.4.4)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.3.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (3.1.40)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (0.4.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 39)) (4.1.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (2.8.1)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (0.10.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 11)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 9)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (4.0.11)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (1.61.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 22)) (0.1.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (4.46.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (41.0.7)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (4.1.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.5.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (3.5.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (4.20.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (2.0.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.0.1->-r requirements.txt (line 43)) (2.1.3)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (8.1.1)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.27.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.0.6)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.12.0)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 13)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.0.1->-r requirements.txt (line 43)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 19)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (7.0.0)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (25.1.2)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.18.1)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.5.8)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.1.6)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.13.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 14)) (3.0.41)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (5.9.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.11.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.25.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (2.21)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (7.4.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.4.4)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.18.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: tomli in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.14)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.13.1)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.8.3)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h29.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h29_queue.log>
# Submitted batch job 35880634
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2023-12-12 18:29:40,600	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2023-12-12 18:29:40,601	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2023-12-12 18:29:45,521	SUCC scripts.py:781 -- --------------------
# 2023-12-12 18:29:45,522	SUCC scripts.py:782 -- Ray runtime started.
# 2023-12-12 18:29:45,522	SUCC scripts.py:783 -- --------------------
# 2023-12-12 18:29:45,522	INFO scripts.py:785 -- Next steps
# 2023-12-12 18:29:45,522	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2023-12-12 18:29:45,522	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2023-12-12 18:29:45,522	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2023-12-12 18:29:45,522	INFO scripts.py:802 -- import ray
# 2023-12-12 18:29:45,522	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2023-12-12 18:29:45,522	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2023-12-12 18:29:45,522	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2023-12-12 18:29:45,522	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2023-12-12 18:29:45,522	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2023-12-12 18:29:45,522	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2023-12-12 18:29:45,522	INFO scripts.py:835 --   ray stop
# 2023-12-12 18:29:45,522	INFO scripts.py:838 -- To view the status of the cluster, use
# 2023-12-12 18:29:45,522	INFO scripts.py:839 --   ray status
# 2023-12-12 18:29:45,522	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2023-12-12 18:29:45,522	INFO scripts.py:844 --   10.203.101.82:8265
# 2023-12-12 18:29:45,523	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2023-12-12 18:29:45,523	INFO scripts.py:952 -- --block
# 2023-12-12 18:29:45,523	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2023-12-12 18:29:45,523	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2023-12-12 18:30:08,412	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2023-12-12 18:30:08,424	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /users/hjamet/.cache/huggingface/token
# Login successful
#
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Downloading .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Downloading .gitattributes: 100%|██████████| 1.52k/1.52k [00:00<00:00, 1.04MB/s]
#
#
# Downloading config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading config.json: 100%|██████████| 1.03k/1.03k [00:00<00:00, 723kB/s]
#
# Fetching 10 files:  10%|█         | 1/10 [00:00<00:01,  6.55it/s]
#
# Downloading README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading README.md: 100%|██████████| 28.0/28.0 [00:00<00:00, 17.1kB/s]
#
# Fetching 10 files:  20%|██        | 2/10 [00:00<00:01,  7.50it/s]
#
# Downloading scheduler.pt:   0%|          | 0.00/627 [00:00<?, ?B/s]
# Downloading scheduler.pt: 100%|██████████| 627/627 [00:00<00:00, 377kB/s]
#
#
# Downloading rng_state.pth:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# Downloading rng_state.pth: 100%|██████████| 14.6k/14.6k [00:00<00:00, 8.16MB/s]
#
#
# Downloading trainer_state.json:   0%|          | 0.00/2.29k [00:00<?, ?B/s]
# Downloading trainer_state.json: 100%|██████████| 2.29k/2.29k [00:00<00:00, 2.79MB/s]
#
#
# Downloading training_args.bin:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading training_args.bin: 100%|██████████| 4.09k/4.09k [00:00<00:00, 2.50MB/s]
#
#
# Downloading model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
#
#
# Downloading (…)er_label_encoder.pkl:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
#
#
#
# Downloading optimizer.pt:   0%|          | 0.00/885M [00:00<?, ?B/s]
#
# Downloading model.safetensors:   2%|▏         | 10.5M/443M [00:00<00:11, 37.5MB/s]
#
#
# Downloading (…)er_label_encoder.pkl: 100%|██████████| 1.40M/1.40M [00:00<00:00, 2.99MB/s]
# Downloading (…)er_label_encoder.pkl: 100%|██████████| 1.40M/1.40M [00:00<00:00, 2.98MB/s]
#
#
# Downloading model.safetensors:   5%|▍         | 21.0M/443M [00:00<00:13, 30.3MB/s]
#
#
#
# Downloading optimizer.pt:   1%|          | 10.5M/885M [00:00<01:02, 14.0MB/s]
#
#
#
# Downloading optimizer.pt:   2%|▏         | 21.0M/885M [00:00<00:33, 25.8MB/s]
#
# Downloading model.safetensors:   7%|▋         | 31.5M/443M [00:01<00:15, 26.1MB/s]
#
#
#
# Downloading optimizer.pt:   4%|▎         | 31.5M/885M [00:01<00:24, 34.6MB/s]
#
#
#
# Downloading optimizer.pt:   5%|▍         | 41.9M/885M [00:01<00:20, 41.1MB/s]
#
#
#
# Downloading optimizer.pt:   6%|▌         | 52.4M/885M [00:01<00:20, 41.3MB/s]
#
# Downloading model.safetensors:   9%|▉         | 41.9M/443M [00:01<00:18, 21.2MB/s]
#
#
#
# Downloading optimizer.pt:   7%|▋         | 62.9M/885M [00:01<00:19, 42.6MB/s]
#
#
#
# Downloading optimizer.pt:   8%|▊         | 73.4M/885M [00:02<00:20, 40.2MB/s]
#
#
#
# Downloading optimizer.pt:   9%|▉         | 83.9M/885M [00:02<00:21, 36.6MB/s]
#
#
#
# Downloading optimizer.pt:  11%|█         | 94.4M/885M [00:02<00:18, 42.0MB/s]
#
# Downloading model.safetensors:  12%|█▏        | 52.4M/443M [00:02<00:25, 15.4MB/s]
#
#
#
# Downloading optimizer.pt:  12%|█▏        | 105M/885M [00:02<00:17, 45.4MB/s]
#
#
#
# Downloading optimizer.pt:  13%|█▎        | 115M/885M [00:02<00:16, 46.9MB/s]
#
#
#
# Downloading optimizer.pt:  14%|█▍        | 126M/885M [00:03<00:15, 50.3MB/s]
#
#
#
# Downloading optimizer.pt:  15%|█▌        | 136M/885M [00:03<00:16, 45.5MB/s]
#
# Downloading model.safetensors:  14%|█▍        | 62.9M/443M [00:03<00:27, 13.8MB/s]
#
#
#
# Downloading optimizer.pt:  17%|█▋        | 147M/885M [00:03<00:15, 48.3MB/s]
#
#
#
# Downloading optimizer.pt:  18%|█▊        | 157M/885M [00:03<00:14, 50.4MB/s]
#
#
#
# Downloading optimizer.pt:  19%|█▉        | 168M/885M [00:04<00:16, 44.4MB/s]
#
#
#
# Downloading optimizer.pt:  20%|██        | 178M/885M [00:04<00:18, 38.4MB/s]
#
# Downloading model.safetensors:  17%|█▋        | 73.4M/443M [00:04<00:28, 12.9MB/s]
#
#
#
# Downloading optimizer.pt:  21%|██▏       | 189M/885M [00:04<00:16, 42.9MB/s]
#
#
#
# Downloading optimizer.pt:  23%|██▎       | 199M/885M [00:04<00:17, 38.3MB/s]
#
#
#
# Downloading optimizer.pt:  24%|██▎       | 210M/885M [00:05<00:17, 39.6MB/s]
#
# Downloading model.safetensors:  19%|█▉        | 83.9M/443M [00:05<00:28, 12.4MB/s]
#
#
#
# Downloading optimizer.pt:  25%|██▍       | 220M/885M [00:05<00:15, 43.4MB/s]
#
#
#
# Downloading optimizer.pt:  26%|██▌       | 231M/885M [00:05<00:15, 41.1MB/s]
#
#
#
# Downloading optimizer.pt:  27%|██▋       | 241M/885M [00:05<00:14, 45.1MB/s]
#
#
#
# Downloading optimizer.pt:  28%|██▊       | 252M/885M [00:06<00:13, 48.2MB/s]
#
#
#
# Downloading optimizer.pt:  30%|██▉       | 262M/885M [00:06<00:12, 50.1MB/s]
#
# Downloading model.safetensors:  21%|██▏       | 94.4M/443M [00:06<00:28, 12.2MB/s]
#
#
#
# Downloading optimizer.pt:  31%|███       | 273M/885M [00:06<00:11, 52.7MB/s]
#
#
#
# Downloading optimizer.pt:  32%|███▏      | 283M/885M [00:06<00:11, 54.0MB/s]
#
#
#
# Downloading optimizer.pt:  33%|███▎      | 294M/885M [00:06<00:13, 45.5MB/s]
#
# Downloading model.safetensors:  24%|██▎       | 105M/443M [00:07<00:28, 12.0MB/s]
#
#
#
# Downloading optimizer.pt:  34%|███▍      | 304M/885M [00:07<00:13, 42.2MB/s]
#
#
#
# Downloading optimizer.pt:  36%|███▌      | 315M/885M [00:07<00:12, 46.0MB/s]
#
#
#
# Downloading optimizer.pt:  37%|███▋      | 325M/885M [00:07<00:14, 38.8MB/s]
#
#
#
# Downloading optimizer.pt:  38%|███▊      | 336M/885M [00:08<00:14, 38.4MB/s]
#
#
#
# Downloading optimizer.pt:  39%|███▉      | 346M/885M [00:08<00:16, 32.7MB/s]
#
# Downloading model.safetensors:  26%|██▌       | 115M/443M [00:08<00:33, 9.86MB/s]
#
#
#
# Downloading optimizer.pt:  40%|████      | 357M/885M [00:08<00:15, 34.1MB/s]
#
#
#
# Downloading optimizer.pt:  41%|████▏     | 367M/885M [00:08<00:13, 37.8MB/s]
#
#
#
# Downloading optimizer.pt:  43%|████▎     | 377M/885M [00:09<00:13, 38.4MB/s]
#
#
#
# Downloading optimizer.pt:  44%|████▍     | 388M/885M [00:09<00:10, 45.7MB/s]
#
#
#
# Downloading optimizer.pt:  45%|████▌     | 398M/885M [00:09<00:11, 41.8MB/s]
#
# Downloading model.safetensors:  28%|██▊       | 126M/443M [00:10<00:36, 8.70MB/s]
#
#
#
# Downloading optimizer.pt:  46%|████▌     | 409M/885M [00:10<00:16, 28.1MB/s]
#
#
#
# Downloading optimizer.pt:  47%|████▋     | 419M/885M [00:10<00:19, 23.4MB/s]
#
#
#
# Downloading optimizer.pt:  49%|████▊     | 430M/885M [00:11<00:16, 28.3MB/s]
#
#
#
# Downloading optimizer.pt:  50%|████▉     | 440M/885M [00:11<00:13, 31.9MB/s]
#
#
#
# Downloading optimizer.pt:  51%|█████     | 451M/885M [00:11<00:11, 36.6MB/s]
#
#
#
# Downloading optimizer.pt:  52%|█████▏    | 461M/885M [00:11<00:10, 41.1MB/s]
#
#
#
# Downloading optimizer.pt:  53%|█████▎    | 472M/885M [00:11<00:09, 44.5MB/s]
#
#
#
# Downloading optimizer.pt:  54%|█████▍    | 482M/885M [00:12<00:08, 48.4MB/s]
#
# Downloading model.safetensors:  31%|███       | 136M/443M [00:12<00:42, 7.20MB/s]
#
#
#
# Downloading optimizer.pt:  56%|█████▌    | 493M/885M [00:12<00:07, 51.0MB/s]
#
#
#
# Downloading optimizer.pt:  57%|█████▋    | 503M/885M [00:12<00:08, 46.0MB/s]
#
#
#
# Downloading optimizer.pt:  58%|█████▊    | 514M/885M [00:12<00:08, 44.9MB/s]
#
#
#
# Downloading optimizer.pt:  59%|█████▉    | 524M/885M [00:12<00:07, 48.4MB/s]
#
#
#
# Downloading optimizer.pt:  60%|██████    | 535M/885M [00:13<00:07, 49.8MB/s]
#
#
#
# Downloading optimizer.pt:  62%|██████▏   | 545M/885M [00:13<00:06, 52.6MB/s]
#
#
#
# Downloading optimizer.pt:  63%|██████▎   | 556M/885M [00:13<00:06, 51.3MB/s]
#
#
#
# Downloading optimizer.pt:  64%|██████▍   | 566M/885M [00:13<00:07, 40.1MB/s]
#
#
#
# Downloading optimizer.pt:  65%|██████▌   | 577M/885M [00:14<00:07, 39.4MB/s]
#
#
#
# Downloading optimizer.pt:  66%|██████▋   | 587M/885M [00:14<00:06, 43.4MB/s]
#
#
#
# Downloading optimizer.pt:  68%|██████▊   | 598M/885M [00:14<00:07, 40.6MB/s]
#
#
#
# Downloading optimizer.pt:  69%|██████▊   | 608M/885M [00:15<00:08, 33.5MB/s]
#
#
#
# Downloading optimizer.pt:  70%|██████▉   | 619M/885M [00:15<00:07, 38.0MB/s]
#
#
#
# Downloading optimizer.pt:  71%|███████   | 629M/885M [00:15<00:06, 37.6MB/s]
#
#
#
# Downloading optimizer.pt:  72%|███████▏  | 640M/885M [00:15<00:06, 38.9MB/s]
#
#
#
# Downloading optimizer.pt:  73%|███████▎  | 650M/885M [00:16<00:06, 38.7MB/s]
#
#
#
# Downloading optimizer.pt:  75%|███████▍  | 661M/885M [00:16<00:05, 43.3MB/s]
#
#
#
# Downloading optimizer.pt:  76%|███████▌  | 671M/885M [00:16<00:04, 46.4MB/s]
#
#
#
# Downloading optimizer.pt:  77%|███████▋  | 682M/885M [00:17<00:06, 33.6MB/s]
#
#
#
# Downloading optimizer.pt:  78%|███████▊  | 692M/885M [00:17<00:05, 34.1MB/s]
#
#
#
# Downloading optimizer.pt:  79%|███████▉  | 703M/885M [00:17<00:04, 38.8MB/s]
#
#
#
# Downloading optimizer.pt:  81%|████████  | 713M/885M [00:18<00:06, 27.8MB/s]
#
#
#
# Downloading optimizer.pt:  82%|████████▏ | 724M/885M [00:18<00:07, 22.9MB/s]
#
#
#
# Downloading optimizer.pt:  83%|████████▎ | 734M/885M [00:18<00:05, 28.0MB/s]
#
#
#
# Downloading optimizer.pt:  84%|████████▍ | 744M/885M [00:19<00:04, 30.6MB/s]
#
#
#
# Downloading optimizer.pt:  85%|████████▌ | 755M/885M [00:19<00:03, 38.4MB/s]
#
#
#
# Downloading optimizer.pt:  86%|████████▋ | 765M/885M [00:19<00:02, 41.1MB/s]
#
#
#
# Downloading optimizer.pt:  88%|████████▊ | 776M/885M [00:19<00:02, 38.4MB/s]
#
#
#
# Downloading optimizer.pt:  89%|████████▉ | 786M/885M [00:20<00:02, 36.3MB/s]
#
#
#
# Downloading optimizer.pt:  90%|█████████ | 797M/885M [00:20<00:02, 35.8MB/s]
#
#
#
# Downloading optimizer.pt:  91%|█████████ | 807M/885M [00:20<00:02, 30.8MB/s]
#
#
#
# Downloading optimizer.pt:  92%|█████████▏| 818M/885M [00:21<00:02, 32.7MB/s]
#
#
#
# Downloading optimizer.pt:  94%|█████████▎| 828M/885M [00:21<00:01, 39.9MB/s]
#
#
#
# Downloading optimizer.pt:  95%|█████████▍| 839M/885M [00:21<00:01, 44.5MB/s]
#
#
#
# Downloading optimizer.pt:  96%|█████████▌| 849M/885M [00:21<00:00, 41.6MB/s]
#
#
#
# Downloading optimizer.pt:  97%|█████████▋| 860M/885M [00:21<00:00, 45.2MB/s]
#
#
#
# Downloading optimizer.pt:  98%|█████████▊| 870M/885M [00:22<00:00, 44.8MB/s]
#
#
#
# Downloading optimizer.pt: 100%|█████████▉| 881M/885M [00:22<00:00, 48.0MB/s]
# Downloading optimizer.pt: 100%|██████████| 885M/885M [00:22<00:00, 39.3MB/s]
#
#
# Downloading model.safetensors:  33%|███▎      | 147M/443M [00:25<02:20, 2.10MB/s]
#
# Downloading model.safetensors:  36%|███▌      | 157M/443M [00:38<03:23, 1.40MB/s]
#
# Downloading model.safetensors:  36%|███▌      | 157M/443M [00:49<03:23, 1.40MB/s]
#
# Downloading model.safetensors:  38%|███▊      | 168M/443M [00:50<03:52, 1.18MB/s]
#
# Downloading model.safetensors:  40%|████      | 178M/443M [01:01<03:59, 1.10MB/s]
#
# Downloading model.safetensors:  43%|████▎     | 189M/443M [01:12<03:56, 1.07MB/s]
#
# Downloading model.safetensors:  45%|████▌     | 199M/443M [01:16<03:11, 1.27MB/s]
#
# Downloading model.safetensors:  47%|████▋     | 210M/443M [01:25<03:07, 1.24MB/s]
#
# Downloading model.safetensors:  50%|████▉     | 220M/443M [01:33<02:51, 1.30MB/s]
#
# Downloading model.safetensors:  52%|█████▏    | 231M/443M [01:41<02:44, 1.29MB/s]
#
# Downloading model.safetensors:  54%|█████▍    | 241M/443M [01:49<02:38, 1.27MB/s]
#
# Downloading model.safetensors:  57%|█████▋    | 252M/443M [02:01<02:50, 1.12MB/s]
#
# Downloading model.safetensors:  59%|█████▉    | 262M/443M [02:08<02:28, 1.21MB/s]
#
# Downloading model.safetensors:  62%|██████▏   | 273M/443M [02:17<02:18, 1.23MB/s]
#
# Downloading model.safetensors:  64%|██████▍   | 283M/443M [02:22<01:55, 1.38MB/s]
#
# Downloading model.safetensors:  66%|██████▋   | 294M/443M [02:30<01:47, 1.39MB/s]
#
# Downloading model.safetensors:  69%|██████▊   | 304M/443M [02:37<01:39, 1.39MB/s]
#
# Downloading model.safetensors:  71%|███████   | 315M/443M [02:47<01:42, 1.25MB/s]
#
# Downloading model.safetensors:  71%|███████   | 315M/443M [02:59<01:42, 1.25MB/s]
#
# Downloading model.safetensors:  73%|███████▎  | 325M/443M [03:01<01:51, 1.05MB/s]
#
# Downloading model.safetensors:  73%|███████▎  | 325M/443M [03:19<01:51, 1.05MB/s]
#
# Downloading model.safetensors:  76%|███████▌  | 336M/443M [03:19<02:06, 846kB/s]
#
# Downloading model.safetensors:  78%|███████▊  | 346M/443M [03:23<01:31, 1.06MB/s]
#
# Downloading model.safetensors:  81%|████████  | 357M/443M [03:25<01:01, 1.41MB/s]
#
# Downloading model.safetensors:  83%|████████▎ | 367M/443M [03:26<00:40, 1.88MB/s]
#
# Downloading model.safetensors:  85%|████████▌ | 377M/443M [03:27<00:25, 2.52MB/s]
#
# Downloading model.safetensors:  88%|████████▊ | 388M/443M [03:28<00:16, 3.28MB/s]
#
# Downloading model.safetensors:  90%|█████████ | 398M/443M [03:29<00:10, 4.07MB/s]
#
# Downloading model.safetensors:  92%|█████████▏| 409M/443M [03:30<00:06, 4.81MB/s]
#
# Downloading model.safetensors:  95%|█████████▍| 419M/443M [03:32<00:04, 5.27MB/s]
#
# Downloading model.safetensors:  97%|█████████▋| 430M/443M [03:35<00:02, 4.25MB/s]
#
# Downloading model.safetensors: 100%|█████████▉| 440M/443M [03:47<00:01, 1.98MB/s]
#
# Downloading model.safetensors: 100%|██████████| 443M/443M [03:49<00:00, 1.84MB/s]
# Downloading model.safetensors: 100%|██████████| 443M/443M [03:49<00:00, 1.92MB/s]
#
# Fetching 10 files:  40%|████      | 4/10 [03:50<07:13, 72.21s/it]
# Fetching 10 files: 100%|██████████| 10/10 [03:50<00:00, 23.05s/it]
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# --------------- ...AND COMPUTE FRENCH_DIFFICULTY PREDICTIONS --------------- #
french_difficulty_predictions = create_launcher("french_difficulty")()
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (2.0.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.15.2)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (3.5.0)
# Requirement already satisfied: torch==2.0.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (2.0.1)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.4.0.1)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.9.0.58)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (1.12)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (8.5.0.96)
# Requirement already satisfied: triton==2.0.0 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.0.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.101)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.4.91)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.2.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (4.8.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.10.3.66)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (3.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (11.7.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.venv/lib/python3.9/site-packages (from torch==2.0.1->-r requirements.txt (line 43)) (2.14.3)
# Requirement already satisfied: wheel in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (0.42.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r requirements.txt (line 43)) (58.1.0)
# Requirement already satisfied: lit in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (17.0.6)
# Requirement already satisfied: cmake in ./.venv/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 43)) (3.27.9)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2023.10.0)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.70.15)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (1.26.2)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (14.0.1)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.16.4)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (4.66.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (1.10.13)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (1.20.0)
# Requirement already satisfied: psutil>=5.6.0 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 9)) (5.9.6)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 13)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 16)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 18)) (0.1.3)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (4.35.2)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 19)) (0.23.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (2023.10.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 24)) (1.11.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 25)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 29)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 31)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 33)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 35)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 37)) (0.3.7)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.3.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (0.4.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 38)) (3.1.40)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 39)) (4.1.0)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (0.10.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 42)) (2.8.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 39)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 11)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 9)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (4.0.11)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (1.61.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 22)) (0.1.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (6.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (4.46.0)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (4.1.1)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (3.5.1)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (4.20.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.0.7)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (1.59.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (0.7.2)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (2.0.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.0.1->-r requirements.txt (line 43)) (2.1.3)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.0.6)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (7.12.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (5.5.1)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 14)) (6.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 13)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.0.1->-r requirements.txt (line 43)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 19)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 38)) (5.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 25)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 42)) (7.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.1.6)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.14.0)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (25.1.2)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.6.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (1.5.8)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (8.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (0.13.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 42)) (2023.11.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 14)) (3.0.41)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (5.9.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.11.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.25.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 42)) (2.21)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.4.4)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.18.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (7.4.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: tomli in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 14)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 31)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.8.3)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 14)) (21.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 14)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h35.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1212-18h35_queue.log>
# Submitted batch job 35880693
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2023-12-12 18:35:33,895	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2023-12-12 18:35:33,896	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2023-12-12 18:35:39,118	SUCC scripts.py:781 -- --------------------
# 2023-12-12 18:35:39,118	SUCC scripts.py:782 -- Ray runtime started.
# 2023-12-12 18:35:39,118	SUCC scripts.py:783 -- --------------------
# 2023-12-12 18:35:39,119	INFO scripts.py:785 -- Next steps
# 2023-12-12 18:35:39,119	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2023-12-12 18:35:39,119	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2023-12-12 18:35:39,119	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2023-12-12 18:35:39,119	INFO scripts.py:802 -- import ray
# 2023-12-12 18:35:39,119	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2023-12-12 18:35:39,119	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2023-12-12 18:35:39,119	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2023-12-12 18:35:39,119	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2023-12-12 18:35:39,119	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2023-12-12 18:35:39,119	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2023-12-12 18:35:39,119	INFO scripts.py:835 --   ray stop
# 2023-12-12 18:35:39,119	INFO scripts.py:838 -- To view the status of the cluster, use
# 2023-12-12 18:35:39,119	INFO scripts.py:839 --   ray status
# 2023-12-12 18:35:39,119	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2023-12-12 18:35:39,119	INFO scripts.py:844 --   10.203.101.82:8265
# 2023-12-12 18:35:39,119	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2023-12-12 18:35:39,120	INFO scripts.py:952 -- --block
# 2023-12-12 18:35:39,120	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2023-12-12 18:35:39,120	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2023-12-12 18:36:01,960	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2023-12-12 18:36:01,972	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /users/hjamet/.cache/huggingface/token
# Login successful
#
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Downloading config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading config.json: 100%|██████████| 1.03k/1.03k [00:00<00:00, 687kB/s]
#
#
# Downloading .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Downloading .gitattributes: 100%|██████████| 1.52k/1.52k [00:00<00:00, 935kB/s]
#
#
# Downloading README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading README.md: 100%|██████████| 28.0/28.0 [00:00<00:00, 17.0kB/s]
#
# Fetching 10 files:  10%|█         | 1/10 [00:00<00:01,  5.16it/s]
#
# Downloading scheduler.pt:   0%|          | 0.00/627 [00:00<?, ?B/s]
# Downloading scheduler.pt: 100%|██████████| 627/627 [00:00<00:00, 385kB/s]
#
#
# Downloading trainer_state.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# Downloading trainer_state.json: 100%|██████████| 2.10k/2.10k [00:00<00:00, 1.29MB/s]
#
#
# Downloading model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
#
#
# Downloading rng_state.pth:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# Downloading rng_state.pth: 100%|██████████| 14.6k/14.6k [00:00<00:00, 8.73MB/s]
#
#
#
# Downloading optimizer.pt:   0%|          | 0.00/885M [00:00<?, ?B/s]
#
#
#
# Downloading (…)er_label_encoder.pkl:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
#
#
#
#
# Downloading training_args.bin:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading training_args.bin: 100%|██████████| 4.09k/4.09k [00:00<00:00, 4.84MB/s]
#
# Downloading (…)er_label_encoder.pkl: 100%|██████████| 1.40M/1.40M [00:00<00:00, 15.0MB/s]
#
#
# Downloading model.safetensors:   2%|▏         | 10.5M/443M [00:00<00:08, 53.6MB/s]
#
#
# Downloading optimizer.pt:   1%|          | 10.5M/885M [00:00<00:28, 31.1MB/s]
#
# Downloading model.safetensors:   5%|▍         | 21.0M/443M [00:00<00:07, 55.5MB/s]
#
#
# Downloading optimizer.pt:   2%|▏         | 21.0M/885M [00:00<00:19, 44.8MB/s]
#
# Downloading model.safetensors:   7%|▋         | 31.5M/443M [00:00<00:08, 46.4MB/s]
#
#
# Downloading optimizer.pt:   4%|▎         | 31.5M/885M [00:00<00:19, 44.2MB/s]
#
# Downloading model.safetensors:   9%|▉         | 41.9M/443M [00:00<00:09, 42.6MB/s]
#
#
# Downloading optimizer.pt:   5%|▍         | 41.9M/885M [00:00<00:17, 48.1MB/s]
#
# Downloading model.safetensors:  12%|█▏        | 52.4M/443M [00:01<00:10, 38.5MB/s]
#
#
# Downloading optimizer.pt:   6%|▌         | 52.4M/885M [00:01<00:19, 43.0MB/s]
#
#
# Downloading optimizer.pt:   7%|▋         | 62.9M/885M [00:01<00:17, 47.7MB/s]
#
# Downloading model.safetensors:  14%|█▍        | 62.9M/443M [00:01<00:09, 40.5MB/s]
#
#
# Downloading optimizer.pt:   8%|▊         | 73.4M/885M [00:01<00:20, 40.0MB/s]
#
# Downloading model.safetensors:  17%|█▋        | 73.4M/443M [00:01<00:10, 36.0MB/s]
#
# Downloading model.safetensors:  19%|█▉        | 83.9M/443M [00:02<00:10, 35.4MB/s]
#
#
# Downloading optimizer.pt:   9%|▉         | 83.9M/885M [00:02<00:23, 33.9MB/s]
#
# Downloading model.safetensors:  21%|██▏       | 94.4M/443M [00:02<00:08, 40.1MB/s]
#
#
# Downloading optimizer.pt:  11%|█         | 94.4M/885M [00:02<00:20, 38.9MB/s]
#
# Downloading model.safetensors:  24%|██▎       | 105M/443M [00:02<00:07, 43.6MB/s]
#
# Downloading model.safetensors:  26%|██▌       | 115M/443M [00:02<00:07, 44.1MB/s]
#
#
# Downloading optimizer.pt:  12%|█▏        | 105M/885M [00:02<00:25, 30.3MB/s]
#
# Downloading model.safetensors:  28%|██▊       | 126M/443M [00:02<00:06, 47.3MB/s]
#
# Downloading model.safetensors:  31%|███       | 136M/443M [00:03<00:06, 47.6MB/s]
#
#
# Downloading optimizer.pt:  13%|█▎        | 115M/885M [00:03<00:25, 30.0MB/s]
#
#
# Downloading optimizer.pt:  14%|█▍        | 126M/885M [00:03<00:22, 34.4MB/s]
#
# Downloading model.safetensors:  33%|███▎      | 147M/443M [00:03<00:06, 42.4MB/s]
#
# Downloading model.safetensors:  36%|███▌      | 157M/443M [00:03<00:06, 43.9MB/s]
#
#
# Downloading optimizer.pt:  15%|█▌        | 136M/885M [00:03<00:24, 30.3MB/s]
#
#
# Downloading optimizer.pt:  17%|█▋        | 147M/885M [00:04<00:23, 31.4MB/s]
#
# Downloading model.safetensors:  38%|███▊      | 168M/443M [00:04<00:08, 31.0MB/s]
#
#
# Downloading optimizer.pt:  18%|█▊        | 157M/885M [00:04<00:20, 35.7MB/s]
#
#
# Downloading optimizer.pt:  19%|█▉        | 168M/885M [00:04<00:18, 38.4MB/s]
#
#
# Downloading optimizer.pt:  20%|██        | 178M/885M [00:04<00:16, 42.2MB/s]
#
# Downloading model.safetensors:  40%|████      | 178M/443M [00:04<00:10, 25.6MB/s]
#
#
# Downloading optimizer.pt:  21%|██▏       | 189M/885M [00:04<00:15, 45.8MB/s]
#
# Downloading model.safetensors:  43%|████▎     | 189M/443M [00:05<00:09, 28.1MB/s]
#
#
# Downloading optimizer.pt:  23%|██▎       | 199M/885M [00:05<00:14, 48.8MB/s]
#
#
# Downloading optimizer.pt:  24%|██▎       | 210M/885M [00:05<00:13, 50.9MB/s]
#
#
# Downloading optimizer.pt:  25%|██▍       | 220M/885M [00:05<00:12, 53.2MB/s]
#
#
# Downloading optimizer.pt:  26%|██▌       | 231M/885M [00:05<00:11, 55.0MB/s]
#
# Downloading model.safetensors:  45%|████▌     | 199M/443M [00:06<00:12, 19.6MB/s]
#
#
# Downloading optimizer.pt:  27%|██▋       | 241M/885M [00:06<00:14, 45.5MB/s]
#
#
# Downloading optimizer.pt:  28%|██▊       | 252M/885M [00:06<00:12, 49.0MB/s]
#
# Downloading model.safetensors:  47%|████▋     | 210M/443M [00:06<00:10, 22.4MB/s]
#
#
# Downloading optimizer.pt:  30%|██▉       | 262M/885M [00:06<00:12, 49.6MB/s]
#
# Downloading model.safetensors:  50%|████▉     | 220M/443M [00:06<00:08, 27.4MB/s]
#
# Downloading model.safetensors:  52%|█████▏    | 231M/443M [00:06<00:06, 32.6MB/s]
#
#
# Downloading optimizer.pt:  31%|███       | 273M/885M [00:06<00:15, 38.9MB/s]
#
# Downloading model.safetensors:  54%|█████▍    | 241M/443M [00:06<00:05, 37.4MB/s]
#
#
# Downloading optimizer.pt:  32%|███▏      | 283M/885M [00:06<00:14, 42.6MB/s]
#
#
# Downloading optimizer.pt:  33%|███▎      | 294M/885M [00:07<00:13, 44.9MB/s]
#
# Downloading model.safetensors:  57%|█████▋    | 252M/443M [00:07<00:05, 35.6MB/s]
#
#
# Downloading optimizer.pt:  34%|███▍      | 304M/885M [00:07<00:13, 44.1MB/s]
#
# Downloading model.safetensors:  62%|██████▏   | 273M/443M [00:07<00:04, 41.2MB/s]
#
#
# Downloading optimizer.pt:  36%|███▌      | 315M/885M [00:07<00:12, 47.2MB/s]
#
# Downloading model.safetensors:  64%|██████▍   | 283M/443M [00:07<00:03, 44.4MB/s]
#
#
# Downloading optimizer.pt:  37%|███▋      | 325M/885M [00:07<00:11, 49.8MB/s]
#
#
# Downloading optimizer.pt:  38%|███▊      | 336M/885M [00:07<00:10, 51.8MB/s]
#
# Downloading model.safetensors:  66%|██████▋   | 294M/443M [00:08<00:03, 38.3MB/s]
#
#
# Downloading optimizer.pt:  39%|███▉      | 346M/885M [00:08<00:11, 47.0MB/s]
#
# Downloading model.safetensors:  69%|██████▊   | 304M/443M [00:08<00:04, 31.7MB/s]
#
#
# Downloading optimizer.pt:  40%|████      | 357M/885M [00:08<00:13, 37.9MB/s]
#
#
# Downloading optimizer.pt:  41%|████▏     | 367M/885M [00:08<00:12, 42.4MB/s]
#
# Downloading model.safetensors:  71%|███████   | 315M/443M [00:08<00:03, 32.7MB/s]
#
#
# Downloading optimizer.pt:  43%|████▎     | 377M/885M [00:09<00:11, 45.5MB/s]
#
#
# Downloading optimizer.pt:  44%|████▍     | 388M/885M [00:09<00:10, 49.1MB/s]
#
#
# Downloading optimizer.pt:  45%|████▌     | 398M/885M [00:09<00:10, 46.7MB/s]
#
#
# Downloading optimizer.pt:  46%|████▌     | 409M/885M [00:09<00:09, 49.5MB/s]
#
# Downloading model.safetensors:  73%|███████▎  | 325M/443M [00:09<00:05, 23.4MB/s]
#
# Downloading model.safetensors:  76%|███████▌  | 336M/443M [00:10<00:04, 26.3MB/s]
#
#
# Downloading optimizer.pt:  47%|████▋     | 419M/885M [00:10<00:12, 38.0MB/s]
#
# Downloading model.safetensors:  78%|███████▊  | 346M/443M [00:10<00:03, 31.0MB/s]
#
#
# Downloading optimizer.pt:  49%|████▊     | 430M/885M [00:10<00:14, 32.2MB/s]
#
# Downloading model.safetensors:  81%|████████  | 357M/443M [00:10<00:02, 30.1MB/s]
#
#
# Downloading optimizer.pt:  50%|████▉     | 440M/885M [00:10<00:12, 34.5MB/s]
#
# Downloading model.safetensors:  83%|████████▎ | 367M/443M [00:10<00:02, 31.8MB/s]
#
#
# Downloading optimizer.pt:  51%|█████     | 451M/885M [00:10<00:11, 37.3MB/s]
#
# Downloading model.safetensors:  85%|████████▌ | 377M/443M [00:11<00:01, 34.9MB/s]
#
# Downloading model.safetensors:  88%|████████▊ | 388M/443M [00:11<00:01, 39.3MB/s]
#
# Downloading model.safetensors:  90%|█████████ | 398M/443M [00:11<00:01, 43.3MB/s]
#
#
# Downloading optimizer.pt:  52%|█████▏    | 461M/885M [00:11<00:13, 30.6MB/s]
#
# Downloading model.safetensors:  92%|█████████▏| 409M/443M [00:11<00:00, 42.6MB/s]
#
# Downloading model.safetensors:  95%|█████████▍| 419M/443M [00:12<00:00, 38.9MB/s]
#
#
# Downloading optimizer.pt:  53%|█████▎    | 472M/885M [00:12<00:16, 25.8MB/s]
#
# Downloading model.safetensors:  97%|█████████▋| 430M/443M [00:12<00:00, 43.5MB/s]
#
#
# Downloading optimizer.pt:  54%|█████▍    | 482M/885M [00:12<00:14, 27.6MB/s]
#
# Downloading model.safetensors: 100%|█████████▉| 440M/443M [00:12<00:00, 43.7MB/s]
#
#
# Downloading optimizer.pt:  56%|█████▌    | 493M/885M [00:12<00:12, 32.1MB/s]
# Downloading model.safetensors: 100%|██████████| 443M/443M [00:12<00:00, 35.2MB/s]
#
# Fetching 10 files:  40%|████      | 4/10 [00:13<00:21,  3.52s/it]
#
#
# Downloading optimizer.pt:  57%|█████▋    | 503M/885M [00:12<00:10, 36.9MB/s]
#
#
# Downloading optimizer.pt:  58%|█████▊    | 514M/885M [00:12<00:09, 37.5MB/s]
#
#
# Downloading optimizer.pt:  59%|█████▉    | 524M/885M [00:13<00:08, 42.0MB/s]
#
#
# Downloading optimizer.pt:  60%|██████    | 535M/885M [00:13<00:07, 43.9MB/s]
#
#
# Downloading optimizer.pt:  62%|██████▏   | 545M/885M [00:13<00:07, 46.3MB/s]
#
#
# Downloading optimizer.pt:  63%|██████▎   | 556M/885M [00:13<00:06, 49.6MB/s]
#
#
# Downloading optimizer.pt:  64%|██████▍   | 566M/885M [00:13<00:06, 48.3MB/s]
#
#
# Downloading optimizer.pt:  65%|██████▌   | 577M/885M [00:14<00:06, 46.1MB/s]
#
#
# Downloading optimizer.pt:  66%|██████▋   | 587M/885M [00:14<00:06, 49.2MB/s]
#
#
# Downloading optimizer.pt:  68%|██████▊   | 598M/885M [00:14<00:05, 48.3MB/s]
#
#
# Downloading optimizer.pt:  69%|██████▊   | 608M/885M [00:15<00:08, 31.2MB/s]
#
#
# Downloading optimizer.pt:  70%|██████▉   | 619M/885M [00:15<00:07, 35.9MB/s]
#
#
# Downloading optimizer.pt:  71%|███████   | 629M/885M [00:15<00:07, 35.2MB/s]
#
#
# Downloading optimizer.pt:  72%|███████▏  | 640M/885M [00:16<00:06, 36.9MB/s]
#
#
# Downloading optimizer.pt:  73%|███████▎  | 650M/885M [00:16<00:06, 37.1MB/s]
#
#
# Downloading optimizer.pt:  75%|███████▍  | 661M/885M [00:16<00:06, 36.1MB/s]
#
#
# Downloading optimizer.pt:  76%|███████▌  | 671M/885M [00:16<00:05, 40.3MB/s]
#
#
# Downloading optimizer.pt:  77%|███████▋  | 682M/885M [00:16<00:04, 43.3MB/s]
#
#
# Downloading optimizer.pt:  78%|███████▊  | 692M/885M [00:17<00:04, 44.2MB/s]
#
#
# Downloading optimizer.pt:  79%|███████▉  | 703M/885M [00:17<00:03, 47.7MB/s]
#
#
# Downloading optimizer.pt:  81%|████████  | 713M/885M [00:17<00:03, 45.0MB/s]
#
#
# Downloading optimizer.pt:  82%|████████▏ | 724M/885M [00:17<00:03, 45.1MB/s]
#
#
# Downloading optimizer.pt:  83%|████████▎ | 734M/885M [00:18<00:03, 48.5MB/s]
#
#
# Downloading optimizer.pt:  84%|████████▍ | 744M/885M [00:18<00:04, 31.0MB/s]
#
#
# Downloading optimizer.pt:  85%|████████▌ | 755M/885M [00:18<00:03, 35.3MB/s]
#
#
# Downloading optimizer.pt:  86%|████████▋ | 765M/885M [00:19<00:02, 40.2MB/s]
#
#
# Downloading optimizer.pt:  88%|████████▊ | 776M/885M [00:19<00:03, 30.7MB/s]
#
#
# Downloading optimizer.pt:  89%|████████▉ | 786M/885M [00:20<00:03, 28.9MB/s]
#
#
# Downloading optimizer.pt:  90%|█████████ | 797M/885M [00:20<00:02, 33.7MB/s]
#
#
# Downloading optimizer.pt:  91%|█████████ | 807M/885M [00:20<00:02, 27.1MB/s]
#
#
# Downloading optimizer.pt:  92%|█████████▏| 818M/885M [00:21<00:02, 30.0MB/s]
#
#
# Downloading optimizer.pt:  94%|█████████▎| 828M/885M [00:21<00:01, 30.6MB/s]
#
#
# Downloading optimizer.pt:  95%|█████████▍| 839M/885M [00:21<00:01, 37.2MB/s]
#
#
# Downloading optimizer.pt:  96%|█████████▌| 849M/885M [00:21<00:00, 41.5MB/s]
#
#
# Downloading optimizer.pt:  97%|█████████▋| 860M/885M [00:21<00:00, 45.6MB/s]
#
#
# Downloading optimizer.pt:  98%|█████████▊| 870M/885M [00:22<00:00, 48.2MB/s]
#
#
# Downloading optimizer.pt: 100%|█████████▉| 881M/885M [00:22<00:00, 49.4MB/s]
# Downloading optimizer.pt: 100%|██████████| 885M/885M [00:22<00:00, 39.7MB/s]
#
# Fetching 10 files:  50%|█████     | 5/10 [00:22<00:26,  5.25s/it]
# Fetching 10 files: 100%|██████████| 10/10 [00:22<00:00,  2.28s/it]
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------ FIX LJL LABELS ------------------------------ #
# (for some reason, the label encoder did not work properly)

transformation = {0: "level1", 1: "level2", 2: "level3", 3: "level4"}
ljl_transformed = np.vectorize(transformation.get)(ljl_predictions)
ljl_transformed

# %%
# ----------------------------- SAVE PREDICTIONS ----------------------------- #
import pandas as pd

# Create directory if it does not exist
save_path = os.path.join(pwd, "results", "OpenSourceModelsEvaluation")
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Save predictions
pd.concat(
    [
        csv_list["ljl"]["test"],
        pd.DataFrame({"predictions": ljl_transformed}),
    ],
    axis=1,
).to_csv(os.path.join(save_path, "ljl.csv"))

pd.concat(
    [
        csv_list["sentences"]["test"],
        pd.DataFrame({"predictions": sentences_predictions}),
    ],
    axis=1,
).to_csv(os.path.join(save_path, "sentences.csv"))

pd.concat(
    [
        csv_list["french_difficulty"]["test"],
        pd.DataFrame({"predictions": french_difficulty_predictions}),
    ],
    axis=1,
).to_csv(os.path.join(save_path, "french_difficulty.csv"))

# %%
# ------------------------------ COMPUTE METRICS ----------------------------- #
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

save_path = os.path.join(pwd, "results", "OpenSourceModelsEvaluation")

# Load predictions
predictions = {
    "ljl": pd.read_csv(os.path.join(save_path, "ljl.csv")),
    "sentences": pd.read_csv(os.path.join(save_path, "sentences.csv")),
    "french_difficulty": pd.read_csv(os.path.join(save_path, "french_difficulty.csv")),
}

# Compute metrics line = mode, column = metric
## Accuracy, F1, Precision macro, Precision micro, Recall macro, Recall micro
metrics = pd.DataFrame(
    np.zeros((len(predictions), 6)),
    index=predictions.keys(),
    columns=[
        "accuracy",
        "f1",
        "precision_macro",
        "precision_micro",
        "recall_macro",
        "recall_micro",
    ],
)

# Compute metrics
for key in predictions.keys():
    metrics.loc[key, "accuracy"] = accuracy_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
    )
    metrics.loc[key, "f1"] = f1_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
        average="macro",
    )
    metrics.loc[key, "precision_macro"] = precision_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
        average="macro",
    )
    metrics.loc[key, "precision_micro"] = precision_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
        average="micro",
    )
    metrics.loc[key, "recall_macro"] = recall_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
        average="macro",
    )
    metrics.loc[key, "recall_micro"] = recall_score(
        predictions[key]["difficulty"].tolist(),
        predictions[key]["predictions"].tolist(),
        average="micro",
    )

# Sort results by f1 score
metrics = metrics.sort_values(by="f1", ascending=False)

# Save results
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "bert_metrics.csv",
)
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
metrics.to_csv(path)

# Round results
metrics = metrics.round(4)
metrics.style.background_gradient(
    cmap="Blues",
    axis=0,
)
# Out:
# <style type="text/css">
# #T_73daf_row0_col0, #T_73daf_row0_col1, #T_73daf_row0_col2, #T_73daf_row0_col3, #T_73daf_row0_col4, #T_73daf_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_73daf_row1_col0, #T_73daf_row1_col3, #T_73daf_row1_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_73daf_row1_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_73daf_row1_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_73daf_row1_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_73daf_row2_col0, #T_73daf_row2_col1, #T_73daf_row2_col2, #T_73daf_row2_col3, #T_73daf_row2_col4, #T_73daf_row2_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_73daf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73daf_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_73daf_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_73daf_level0_col2" class="col_heading level0 col2" >precision_macro</th>
#       <th id="T_73daf_level0_col3" class="col_heading level0 col3" >precision_micro</th>
#       <th id="T_73daf_level0_col4" class="col_heading level0 col4" >recall_macro</th>
#       <th id="T_73daf_level0_col5" class="col_heading level0 col5" >recall_micro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73daf_level0_row0" class="row_heading level0 row0" >sentences</th>
#       <td id="T_73daf_row0_col0" class="data row0 col0" >0.822900</td>
#       <td id="T_73daf_row0_col1" class="data row0 col1" >0.821200</td>
#       <td id="T_73daf_row0_col2" class="data row0 col2" >0.826800</td>
#       <td id="T_73daf_row0_col3" class="data row0 col3" >0.822900</td>
#       <td id="T_73daf_row0_col4" class="data row0 col4" >0.822900</td>
#       <td id="T_73daf_row0_col5" class="data row0 col5" >0.822900</td>
#     </tr>
#     <tr>
#       <th id="T_73daf_level0_row1" class="row_heading level0 row1" >ljl</th>
#       <td id="T_73daf_row1_col0" class="data row1 col0" >0.624700</td>
#       <td id="T_73daf_row1_col1" class="data row1 col1" >0.631100</td>
#       <td id="T_73daf_row1_col2" class="data row1 col2" >0.626700</td>
#       <td id="T_73daf_row1_col3" class="data row1 col3" >0.624700</td>
#       <td id="T_73daf_row1_col4" class="data row1 col4" >0.640800</td>
#       <td id="T_73daf_row1_col5" class="data row1 col5" >0.624700</td>
#     </tr>
#     <tr>
#       <th id="T_73daf_level0_row2" class="row_heading level0 row2" >french_difficulty</th>
#       <td id="T_73daf_row2_col0" class="data row2 col0" >0.522900</td>
#       <td id="T_73daf_row2_col1" class="data row2 col1" >0.512600</td>
#       <td id="T_73daf_row2_col2" class="data row2 col2" >0.528200</td>
#       <td id="T_73daf_row2_col3" class="data row2 col3" >0.522900</td>
#       <td id="T_73daf_row2_col4" class="data row2 col4" >0.522900</td>
#       <td id="T_73daf_row2_col5" class="data row2 col5" >0.522900</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Mistral 7B

# %%
from transformers import AutoTokenizer
from datasets import Dataset
import pandas as pd
from sklearn.preprocessing import LabelEncoder


def prepare_mistral_datasets(
    df: pd.DataFrame,
    tokenizer: AutoTokenizer,
    context: str = None,
    split_size: float = 0.2,
):
    # Encode labels
    label_encoder = LabelEncoder()
    df["difficulty"] = label_encoder.fit_transform(df["difficulty"])
    df.astype({"difficulty": "str"})

    # Create dataset
    dataset = Dataset.from_pandas(df)

    # Remove labels if split_size is 0 (for inference)
    if split_size == 0:
        dataset = dataset.map(
            lambda example: {"sentence": example["sentence"], "difficulty": ""},
            remove_columns=["difficulty"],
        )

    # Add context, label and tokenize
    max_length = 512

    def simple_tokenize(e):
        result = tokenizer(
            e["sentence"],
        )
        return result

    encoded_sentences = dataset.map(simple_tokenize)
    ## Truncate sentences
    truncated_dataset = encoded_sentences.map(
        lambda e: {
            "sentence": tokenizer.decode(e["input_ids"][: int(max_length)]),
        }
    ).remove_columns(["input_ids", "attention_mask"])

    # Determine Context size
    full_context_string = f"[INST] <<SYS>>\n{context if context is not None else ''}\n<</SYS>>\n\n [/INST] {truncated_dataset['difficulty'][0]}"
    context_length = len(tokenizer(full_context_string)["input_ids"])
    max_length = int(max_length + context_length) + 2

    def tokenize(e):
        context_str = (
            f"[INST] <<SYS>>\n{context if context is not None else ''}\n<</SYS>>\n\n"
        )
        formated = f"{context_str}{e['sentence']} [/INST] {e['difficulty']}"
        result = tokenizer(
            formated, padding="max_length", truncation=True, max_length=max_length
        )
        result["labels"] = result["input_ids"].copy()
        return result

    encoded_dataset = truncated_dataset.map(tokenize)

    # Convertir les listes en tensors
    encoded_dataset.set_format(
        "torch", columns=["input_ids", "attention_mask", "labels"]
    )

    # Remove unnecessary columns
    encoded_dataset = encoded_dataset.remove_columns(["sentence", "difficulty"])

    # Split into train and test
    if split_size == 0:
        return encoded_dataset
    split_dataset = encoded_dataset.train_test_split(test_size=split_size)
    train_dataset = split_dataset["train"]
    test_dataset = split_dataset["test"]

    return train_dataset, test_dataset


tokenizer = AutoTokenizer.from_pretrained(
    "bofenghuang/vigostral-7b-chat",
    padding_side="left",
    add_eos_token=True,
    add_bos_token=True,
)
tokenizer.pad_token = tokenizer.eos_token
ljl_test_dataset = prepare_mistral_datasets(
    csv_list["ljl"]["test"], tokenizer=tokenizer, split_size=0
)
# Out:
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]

# %%
# Decode dataset
display(
    pd.Series(
        ljl_test_dataset.map(
            lambda e: {"sentence": tokenizer.decode(e["input_ids"])},
            remove_columns=["input_ids", "attention_mask", "labels"],
        )["sentence"]
    )
    .apply(lambda x: x[-11:])
    .value_counts()
)

pd.Series(
    ljl_test_dataset.map(
        lambda e: {"size": len(e["attention_mask"])},
        remove_columns=["input_ids", "attention_mask", "labels"],
    )["size"]
).astype(int).describe()
# Out:
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# /INST] </s>    413
# Name: count, dtype: int64
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# count    413.0
# mean     535.0
# std        0.0
# min      535.0
# 25%      535.0
# 50%      535.0
# 75%      535.0
# max      535.0
# dtype: float64

# %%
# ---------------------------- SLURMRAY EVALUATION --------------------------- #
import os

import dill
import pandas as pd
import ray.train.huggingface
import ray.train.huggingface.transformers
import torch
from peft import PeftModel
from torch.utils.data import DataLoader
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig


def evaluate_mistral(
    test_set: pd.DataFrame,
    model_name: str = "mistralai/Mistral-7B-v0.1",
    context: str = None,
    pwd: str = ".",
):
    # Fix partial import bug
    import ray.train.huggingface
    import ray.train.huggingface.transformers

    # Charger le tokenizer
    tokenizer = AutoTokenizer.from_pretrained(
        model_name,
        padding_side="left",
        add_bos_token=True,
        trust_remote_code=True,
    )
    tokenizer.pad_token = tokenizer.eos_token

    # Préparer les datasets
    test_dataset = prepare_mistral_datasets(
        test_set, tokenizer, context=context, split_size=0
    )

    # Charger le modèle et le tokenizer
    base_model = AutoModelForCausalLM.from_pretrained(
        os.path.join(pwd, "mistral_trained"),
        device_map="auto",
        use_cache=False,
        trust_remote_code=True,
    )
    model = PeftModel.from_pretrained(base_model, os.path.join(pwd, "mistral_trained"))

    # Move everything to GPU
    model.to("cuda")
    test_loader = DataLoader(test_dataset, batch_size=16)

    # Generate predictions
    with torch.no_grad():
        model.eval()
        predictions_ids = []

        for batch in test_loader:
            input_ids_batch = batch["input_ids"].to("cuda")
            attention_mask_batch = batch["attention_mask"].to("cuda")

            outputs = model.generate(
                input_ids=input_ids_batch,
                attention_mask=attention_mask_batch,
                max_new_tokens=3,
            )

            predictions_ids.extend(outputs)
        predictions = [
            tokenizer.decode(prediction, skip_special_tokens=True)
            for prediction in predictions_ids
        ]
        predictions_series = pd.Series(predictions)

    return predictions_series

# %%
# ------------------------------- RAY LAUNCHER ------------------------------- #
from slurmray.RayLauncher import RayLauncher

mistral_launcher_builder = lambda dataset, context: RayLauncher(
    project_name="mistral_base_difficulty_estimation",
    func=evaluate_mistral,
    args={
        "test_set": csv_list[dataset]["test"],
        "model_name": "bofenghuang/vigostral-7b-chat",
        "context": context,
        "pwd": "/scratch/hjamet",
    },
    modules=[],
    node_nbr=1,
    use_gpu=True,
    memory=128,
    max_running_time=60,
    server_run=True,
    server_ssh="curnagl.dcsr.unil.ch",
    server_username="hjamet",
)

# %%
# ---------------------------- EVALUATE MISTRAL... --------------------------- #
from sklearn.preprocessing import LabelEncoder


def evaluate_mistral_local(dataset: str, context: bool = False):
    # Define context
    if context:
        context_sentence = "Vous êtes un évaluateur linguistique utilisant le Cadre européen commun de référence pour les langues (CECRL). Votre mission est d'attribuer une note de compétence linguistique à ce texte, en utilisant les niveaux du CECRL, allant de A1 (débutant) à C2 (avancé/natif). Évaluez ce texte et attribuez-lui la note correspondante du CECRL."
        context = "CECRL"
    else:
        context_sentence = None
        context = "no-context"

    # Compute predictions
    launcher = mistral_launcher_builder(dataset, context_sentence)
    predictions = launcher()

    # Extract labels
    predictions_extracted = predictions.str.extract(r"\[/INST\].*?(\d)").rename(
        columns={0: "predictions"}
    )
    predictions_extracted["labels"] = csv_list[dataset]["test"]["difficulty"]
    predictions_extracted["generation"] = predictions

    # Encode labels
    label_encoder = LabelEncoder()
    predictions_extracted["labels"] = label_encoder.fit_transform(
        predictions_extracted["labels"]
    )

    # Save predictions
    path = os.path.join(
        pwd,
        "results",
        "OpenSourceModelsEvaluation",
        "mistral",
        f"{dataset}_{context}.csv",
    )
    ## Create directory if it does not exist
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path))
    ## Save predictions
    predictions_extracted.to_csv(path)

    return predictions_extracted

# %%
# --------------------------------- ...ON LJL -------------------------------- #
ljl_mistral_predictions = evaluate_mistral_local("ljl", context=False)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1801-19h52.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1801-19h52_queue.log>
# Submitted batch job 37142044
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2024-01-18 19:52:32,371	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-18 19:52:32,371	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2024-01-18 19:52:37,220	SUCC scripts.py:781 -- --------------------
# 2024-01-18 19:52:37,220	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-18 19:52:37,220	SUCC scripts.py:783 -- --------------------
# 2024-01-18 19:52:37,220	INFO scripts.py:785 -- Next steps
# 2024-01-18 19:52:37,220	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-18 19:52:37,220	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2024-01-18 19:52:37,220	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-18 19:52:37,220	INFO scripts.py:802 -- import ray
# 2024-01-18 19:52:37,220	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2024-01-18 19:52:37,220	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-18 19:52:37,220	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-18 19:52:37,220	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-18 19:52:37,220	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-18 19:52:37,220	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-18 19:52:37,220	INFO scripts.py:835 --   ray stop
# 2024-01-18 19:52:37,220	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-18 19:52:37,220	INFO scripts.py:839 --   ray status
# 2024-01-18 19:52:37,221	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-18 19:52:37,221	INFO scripts.py:844 --   10.203.101.82:8265
# 2024-01-18 19:52:37,221	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-18 19:52:37,221	INFO scripts.py:952 -- --block
# 2024-01-18 19:52:37,221	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-18 19:52:37,221	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-18 19:53:01,109	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2024-01-18 19:53:01,122	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 15862.93 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:  24%|██▍       | 99/413 [00:00<00:00, 665.55 examples/s]
# Map:  53%|█████▎    | 217/413 [00:00<00:00, 880.31 examples/s]
# Map:  86%|████████▌ | 355/413 [00:00<00:00, 1078.79 examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 908.06 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:   9%|▉         | 38/413 [00:00<00:01, 365.98 examples/s]
# Map:  19%|█▉        | 79/413 [00:00<00:00, 386.52 examples/s]
# Map:  32%|███▏      | 132/413 [00:00<00:00, 365.31 examples/s]
# Map:  41%|████      | 170/413 [00:00<00:00, 367.13 examples/s]
# Map:  51%|█████     | 210/413 [00:00<00:00, 373.69 examples/s]
# Map:  63%|██████▎   | 259/413 [00:00<00:00, 350.66 examples/s]
# Map:  74%|███████▎  | 304/413 [00:00<00:00, 329.61 examples/s]
# Map:  83%|████████▎ | 344/413 [00:01<00:00, 292.38 examples/s]
# Map:  95%|█████████▌| 393/413 [00:01<00:00, 300.52 examples/s]
# Map: 100%|██████████| 413/413 [00:01<00:00, 322.70 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:  36%|███▌      | 147/413 [00:00<00:00, 1444.68 examples/s]
# Map:  71%|███████   | 292/413 [00:00<00:00, 1436.98 examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 1070.78 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:10<00:10, 10.11s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.90s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.38s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# --------------------------------- ...ON LJL -------------------------------- #
ljl_mistral_predictions = evaluate_mistral_local("ljl", context=True)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1801-21h11.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1801-21h11_queue.log>
# Submitted batch job 37142945
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2024-01-18 21:11:33,852	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-18 21:11:33,853	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2024-01-18 21:11:38,695	SUCC scripts.py:781 -- --------------------
# 2024-01-18 21:11:38,695	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-18 21:11:38,695	SUCC scripts.py:783 -- --------------------
# 2024-01-18 21:11:38,695	INFO scripts.py:785 -- Next steps
# 2024-01-18 21:11:38,695	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-18 21:11:38,695	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2024-01-18 21:11:38,695	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-18 21:11:38,695	INFO scripts.py:802 -- import ray
# 2024-01-18 21:11:38,696	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2024-01-18 21:11:38,696	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-18 21:11:38,696	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-18 21:11:38,696	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-18 21:11:38,696	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-18 21:11:38,696	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-18 21:11:38,696	INFO scripts.py:835 --   ray stop
# 2024-01-18 21:11:38,696	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-18 21:11:38,696	INFO scripts.py:839 --   ray status
# 2024-01-18 21:11:38,696	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-18 21:11:38,696	INFO scripts.py:844 --   10.203.101.82:8265
# 2024-01-18 21:11:38,696	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-18 21:11:38,696	INFO scripts.py:952 -- --block
# 2024-01-18 21:11:38,696	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-18 21:11:38,696	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-18 21:12:02,654	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2024-01-18 21:12:02,667	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 16519.31 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:  40%|███▉      | 165/413 [00:00<00:00, 1615.27 examples/s]
# Map:  98%|█████████▊| 406/413 [00:00<00:00, 1586.99 examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 1003.77 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:  11%|█         | 44/413 [00:00<00:00, 429.46 examples/s]
# Map:  23%|██▎       | 95/413 [00:00<00:01, 240.13 examples/s]
# Map:  31%|███       | 128/413 [00:00<00:01, 261.82 examples/s]
# Map:  39%|███▉      | 163/413 [00:00<00:00, 284.21 examples/s]
# Map:  49%|████▊     | 201/413 [00:00<00:00, 310.34 examples/s]
# Map:  58%|█████▊    | 239/413 [00:00<00:00, 328.13 examples/s]
# Map:  67%|██████▋   | 277/413 [00:00<00:00, 340.27 examples/s]
# Map:  76%|███████▌  | 313/413 [00:00<00:00, 343.32 examples/s]
# Map:  85%|████████▍ | 350/413 [00:01<00:00, 348.59 examples/s]
# Map:  97%|█████████▋| 401/413 [00:01<00:00, 341.91 examples/s]
# Map: 100%|██████████| 413/413 [00:01<00:00, 314.89 examples/s]
#
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]
# Map:  23%|██▎       | 95/413 [00:00<00:00, 758.00 examples/s]
# Map:  43%|████▎     | 179/413 [00:00<00:00, 797.14 examples/s]
# Map:  72%|███████▏  | 299/413 [00:00<00:00, 965.94 examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 778.01 examples/s]
# Map: 100%|██████████| 413/413 [00:00<00:00, 796.15 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:09<00:09,  9.73s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.64s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.11s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------- ON SENTENCES ------------------------------- #
sentences_mistral_predictions = evaluate_mistral_local("sentences", context=False)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1901-00h02.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1901-00h02_queue.log>
# Submitted batch job 37144603
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2024-01-19 00:02:57,579	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-19 00:02:57,579	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2024-01-19 00:03:02,713	SUCC scripts.py:781 -- --------------------
# 2024-01-19 00:03:02,713	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-19 00:03:02,713	SUCC scripts.py:783 -- --------------------
# 2024-01-19 00:03:02,713	INFO scripts.py:785 -- Next steps
# 2024-01-19 00:03:02,713	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-19 00:03:02,713	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2024-01-19 00:03:02,713	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-19 00:03:02,713	INFO scripts.py:802 -- import ray
# 2024-01-19 00:03:02,713	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2024-01-19 00:03:02,713	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-19 00:03:02,713	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-19 00:03:02,713	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-19 00:03:02,713	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-19 00:03:02,713	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-19 00:03:02,714	INFO scripts.py:835 --   ray stop
# 2024-01-19 00:03:02,714	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-19 00:03:02,714	INFO scripts.py:839 --   ray status
# 2024-01-19 00:03:02,714	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-19 00:03:02,714	INFO scripts.py:844 --   10.203.101.82:8265
# 2024-01-19 00:03:02,714	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-19 00:03:02,714	INFO scripts.py:952 -- --block
# 2024-01-19 00:03:02,714	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-19 00:03:02,714	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-19 00:03:25,421	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2024-01-19 00:03:25,434	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 17181.41 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 4455.88 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 4169.03 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map:  47%|████▋     | 227/480 [00:00<00:00, 2141.88 examples/s]
# Map:  99%|█████████▉| 475/480 [00:00<00:00, 1805.44 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 1744.01 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map:  67%|██████▋   | 320/480 [00:00<00:00, 3169.60 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 1290.88 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:10<00:10, 10.13s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.83s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.33s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------- ON SENTENCES ------------------------------- #
sentences_mistral_predictions = evaluate_mistral_local("sentences", context=True)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1901-11h43.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1901-11h43_queue.log>
# Submitted batch job 37153289
# IP Head: 10.203.101.88:6379
# STARTING HEAD at dnagpu008
# 2024-01-19 11:58:42,340	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-19 11:58:42,341	INFO scripts.py:744 -- Local node IP: 10.203.101.88
# 2024-01-19 11:58:46,449	SUCC scripts.py:781 -- --------------------
# 2024-01-19 11:58:46,449	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-19 11:58:46,449	SUCC scripts.py:783 -- --------------------
# 2024-01-19 11:58:46,449	INFO scripts.py:785 -- Next steps
# 2024-01-19 11:58:46,449	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-19 11:58:46,449	INFO scripts.py:791 --   ray start --address='10.203.101.88:6379'
# 2024-01-19 11:58:46,449	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-19 11:58:46,449	INFO scripts.py:802 -- import ray
# 2024-01-19 11:58:46,449	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.88')
# 2024-01-19 11:58:46,449	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-19 11:58:46,449	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.88:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-19 11:58:46,450	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-19 11:58:46,450	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-19 11:58:46,450	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-19 11:58:46,450	INFO scripts.py:835 --   ray stop
# 2024-01-19 11:58:46,450	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-19 11:58:46,450	INFO scripts.py:839 --   ray status
# 2024-01-19 11:58:46,450	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-19 11:58:46,450	INFO scripts.py:844 --   10.203.101.88:8265
# 2024-01-19 11:58:46,450	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-19 11:58:46,450	INFO scripts.py:952 -- --block
# 2024-01-19 11:58:46,450	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-19 11:58:46,450	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-19 11:59:09,789	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.88:6379...
# 2024-01-19 11:59:09,803	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.88:8265
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 12067.05 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map:  98%|█████████▊| 469/480 [00:00<00:00, 4646.13 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 4136.55 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map:  48%|████▊     | 229/480 [00:00<00:00, 2262.56 examples/s]
# Map:  99%|█████████▉| 475/480 [00:00<00:00, 1825.15 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 1750.22 examples/s]
#
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Map:  55%|█████▌    | 265/480 [00:00<00:00, 2616.08 examples/s]
# Map: 100%|██████████| 480/480 [00:00<00:00, 1580.54 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:15<00:15, 15.06s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:21<00:00,  9.80s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:21<00:00, 10.59s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------- ON SENTENCES ------------------------------- #
sentences_mistral_predictions = evaluate_mistral_local(
    "french_difficulty", context=False
)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1901-13h30.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1901-13h30_queue.log>
# Submitted batch job 37154419
# IP Head: 10.203.101.88:6379
# STARTING HEAD at dnagpu008
# 2024-01-19 13:30:30,261	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-19 13:30:30,262	INFO scripts.py:744 -- Local node IP: 10.203.101.88
# 2024-01-19 13:30:35,743	SUCC scripts.py:781 -- --------------------
# 2024-01-19 13:30:35,743	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-19 13:30:35,744	SUCC scripts.py:783 -- --------------------
# 2024-01-19 13:30:35,744	INFO scripts.py:785 -- Next steps
# 2024-01-19 13:30:35,744	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-19 13:30:35,744	INFO scripts.py:791 --   ray start --address='10.203.101.88:6379'
# 2024-01-19 13:30:35,744	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-19 13:30:35,744	INFO scripts.py:802 -- import ray
# 2024-01-19 13:30:35,744	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.88')
# 2024-01-19 13:30:35,744	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-19 13:30:35,744	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.88:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-19 13:30:35,744	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-19 13:30:35,744	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-19 13:30:35,744	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-19 13:30:35,744	INFO scripts.py:835 --   ray stop
# 2024-01-19 13:30:35,744	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-19 13:30:35,744	INFO scripts.py:839 --   ray status
# 2024-01-19 13:30:35,744	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-19 13:30:35,744	INFO scripts.py:844 --   10.203.101.88:8265
# 2024-01-19 13:30:35,744	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-19 13:30:35,745	INFO scripts.py:952 -- --block
# 2024-01-19 13:30:35,745	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-19 13:30:35,745	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-19 13:30:55,762	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.88:6379...
# 2024-01-19 13:30:55,776	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.88:8265
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 17660.69 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  32%|███▏      | 309/960 [00:00<00:00, 2264.28 examples/s]
# Map:  69%|██████▉   | 664/960 [00:00<00:00, 2865.75 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 2873.26 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 2777.48 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  39%|███▉      | 374/960 [00:00<00:00, 2370.68 examples/s]
# Map:  65%|██████▍   | 622/960 [00:00<00:00, 2415.32 examples/s]
# Map:  92%|█████████▏| 881/960 [00:00<00:00, 2063.52 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 1976.34 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  38%|███▊      | 366/960 [00:00<00:00, 3607.49 examples/s]
# Map:  80%|████████  | 770/960 [00:00<00:00, 2942.37 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 1873.63 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:09<00:09,  9.85s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.73s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.22s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------- ON SENTENCES ------------------------------- #
sentences_mistral_predictions = evaluate_mistral_local(
    "french_difficulty", context=True
)
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.41.2.post2)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (23.11.0)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.14.7)
# Requirement already satisfied: deep-translator in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.11.4)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.12.6)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.103.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.5.16)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: modin in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.2.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (13.7.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.1.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.3.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.13.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.99)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.4.0)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (2.1.1+cu121)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.16.1+cu121)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.24.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.4.7)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.5.0)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.1.1+cu121)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2023.10.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (4.8.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (1.12)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.13.1)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (2.1.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.1.2)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 45)) (3.2.1)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.16.4)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in ./.venv/lib/python3.9/site-packages (from deep-translator->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.11.1.1)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (11.5.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (5.9.6)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 8)) (1.10.13)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (8.0.1)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in ./.venv/lib/python3.9/site-packages (from mysql-connector-python->-r requirements.txt (line 18)) (4.21.12)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (0.23.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 21)) (4.35.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 24)) (2.17.2)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (2023.10.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 26)) (1.11.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 27)) (3.8.2)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 33)) (2.15.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: appdirs<2,>=1.4.3 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 39)) (0.3.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (3.1.40)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.38.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (1.3.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (0.4.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 40)) (58.1.0)
# Requirement already satisfied: anyio>=3.0.0 in ./.venv/lib/python3.9/site-packages (from watchfiles->-r requirements.txt (line 41)) (4.1.0)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (3.3.1)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (0.10.0)
# Requirement already satisfied: ray[data,serve,train,tune]<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 44)) (2.8.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio>=3.0.0->watchfiles->-r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 13)) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (4.0.11)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.61.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 24)) (0.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (6.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (4.46.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (4.1.1)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (41.0.7)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (3.5.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.0.7)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (4.20.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (1.59.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (2.0.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 45)) (2.1.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.27.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.0.6)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (7.12.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (8.1.1)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 16)) (5.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 15)) (1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 21)) (0.15.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn->-r requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 44)) (7.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (6.4)
# Requirement already satisfied: pyzmq>=20 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.14.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (8.6.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 44)) (0.13.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.9/site-packages (from jupyter-console->jupyter->modcell->-r requirements.txt (line 16)) (3.0.41)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (5.9.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.25.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 44)) (2.21)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.18.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (7.4.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.13.1)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 16)) (2.19.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 33)) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 16)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1901-15h45.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1901-15h45_queue.log>
# Submitted batch job 37161919
# IP Head: 10.203.101.88:6379
# STARTING HEAD at dnagpu008
# 2024-01-19 16:00:02,587	INFO usage_lib.py:416 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-01-19 16:00:02,587	INFO scripts.py:744 -- Local node IP: 10.203.101.88
# 2024-01-19 16:00:07,491	SUCC scripts.py:781 -- --------------------
# 2024-01-19 16:00:07,491	SUCC scripts.py:782 -- Ray runtime started.
# 2024-01-19 16:00:07,492	SUCC scripts.py:783 -- --------------------
# 2024-01-19 16:00:07,492	INFO scripts.py:785 -- Next steps
# 2024-01-19 16:00:07,492	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-01-19 16:00:07,492	INFO scripts.py:791 --   ray start --address='10.203.101.88:6379'
# 2024-01-19 16:00:07,492	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-01-19 16:00:07,492	INFO scripts.py:802 -- import ray
# 2024-01-19 16:00:07,492	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.88')
# 2024-01-19 16:00:07,492	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-01-19 16:00:07,492	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.88:8265' ray job submit --working-dir . -- python my_script.py
# 2024-01-19 16:00:07,492	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-01-19 16:00:07,492	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-01-19 16:00:07,492	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-01-19 16:00:07,492	INFO scripts.py:835 --   ray stop
# 2024-01-19 16:00:07,492	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-01-19 16:00:07,492	INFO scripts.py:839 --   ray status
# 2024-01-19 16:00:07,492	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-01-19 16:00:07,492	INFO scripts.py:844 --   10.203.101.88:8265
# 2024-01-19 16:00:07,492	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-01-19 16:00:07,493	INFO scripts.py:952 -- --block
# 2024-01-19 16:00:07,493	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-01-19 16:00:07,493	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-01-19 16:00:30,698	INFO worker.py:1489 -- Connecting to existing Ray cluster at address: 10.203.101.88:6379...
# 2024-01-19 16:00:30,712	INFO worker.py:1664 -- Connected to Ray cluster. View the dashboard at 10.203.101.88:8265
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 18198.93 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  63%|██████▎   | 605/960 [00:00<00:00, 5997.23 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 3902.98 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  41%|████      | 390/960 [00:00<00:00, 3862.19 examples/s]
# Map:  87%|████████▋ | 834/960 [00:00<00:00, 1764.98 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 1498.34 examples/s]
#
# Map:   0%|          | 0/960 [00:00<?, ? examples/s]
# Map:  28%|██▊       | 269/960 [00:00<00:00, 2658.06 examples/s]
# Map:  57%|█████▋    | 549/960 [00:00<00:00, 2733.26 examples/s]
# Map:  94%|█████████▍| 903/960 [00:00<00:00, 2522.60 examples/s]
# Map: 100%|██████████| 960/960 [00:00<00:00, 1567.30 examples/s]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:09<00:09,  9.62s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.66s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.11s/it]
# /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %%
# ------------------------------ COMPUTE METRICS ----------------------------- #
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix,
)
from matplotlib import pyplot as plt
import seaborn as sn

# Load predictions
full_metrics = {}
for root, dirs, files in os.walk(
    os.path.join(pwd, "results", "OpenSourceModelsEvaluation", "mistral")
):
    for file in files:
        if file.endswith(".csv"):
            predictions = pd.read_csv(os.path.join(root, file))
            # Compute metrics line = mode, column = metric
            ## Accuracy, F1, Precision macro, Precision micro, Recall macro, Recall micro
            metrics = {}
            metrics["accuracy"] = accuracy_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
            )
            metrics["f1"] = f1_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
                average="macro",
            )
            metrics["precision_macro"] = precision_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
                average="macro",
            )
            metrics["precision_micro"] = precision_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
                average="micro",
            )
            metrics["recall_macro"] = recall_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
                average="macro",
            )
            metrics["recall_micro"] = recall_score(
                predictions["labels"].tolist(),
                predictions["predictions"].tolist(),
                average="micro",
            )

            # Save metrics
            full_metrics[file] = metrics

            # Confusion Matrix
            # Calculer la matrice de confusion


# Create Index
full_metrics

# Round results
metrics_df = pd.DataFrame(full_metrics).T.round(4)

# Create MultiIndex
metrics_df.index = pd.MultiIndex.from_tuples(
    [
        tuple(x.split("_"))
        for x in metrics_df.index.str.replace(".csv", "").str.replace(
            "french_difficulty", "french-difficulty"
        )
    ],
    names=["dataset", "context"],
)

# Sort results by f1 score
metrics_df = metrics_df.sort_values(by="f1", ascending=False)

# Save results
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "mistral_metrics.csv",
)
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
metrics_df.to_csv(path)

# Display results
metrics_df.style.background_gradient(
    cmap="Blues",
    axis=0,
)
# Out:
# /home/lopilo24/UNIL/Lingorank_LLM/.venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <style type="text/css">
# #T_526eb_row0_col0, #T_526eb_row0_col1, #T_526eb_row0_col2, #T_526eb_row0_col3, #T_526eb_row0_col4, #T_526eb_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_526eb_row1_col0, #T_526eb_row1_col3, #T_526eb_row1_col5 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_526eb_row1_col1, #T_526eb_row2_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_526eb_row1_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_526eb_row1_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_526eb_row2_col0, #T_526eb_row2_col3, #T_526eb_row2_col4, #T_526eb_row2_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_526eb_row2_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_526eb_row3_col0, #T_526eb_row3_col3, #T_526eb_row3_col4, #T_526eb_row3_col5 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_526eb_row3_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_526eb_row3_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_526eb_row4_col0, #T_526eb_row4_col3, #T_526eb_row4_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_526eb_row4_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_526eb_row4_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_526eb_row4_col4, #T_526eb_row5_col0, #T_526eb_row5_col1, #T_526eb_row5_col2, #T_526eb_row5_col3, #T_526eb_row5_col4, #T_526eb_row5_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_526eb">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_526eb_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_526eb_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_526eb_level0_col2" class="col_heading level0 col2" >precision_macro</th>
#       <th id="T_526eb_level0_col3" class="col_heading level0 col3" >precision_micro</th>
#       <th id="T_526eb_level0_col4" class="col_heading level0 col4" >recall_macro</th>
#       <th id="T_526eb_level0_col5" class="col_heading level0 col5" >recall_micro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_526eb_level0_row0" class="row_heading level0 row0" >sentences</th>
#       <th id="T_526eb_level1_row0" class="row_heading level1 row0" >CECRL</th>
#       <td id="T_526eb_row0_col0" class="data row0 col0" >0.747900</td>
#       <td id="T_526eb_row0_col1" class="data row0 col1" >0.734700</td>
#       <td id="T_526eb_row0_col2" class="data row0 col2" >0.773900</td>
#       <td id="T_526eb_row0_col3" class="data row0 col3" >0.747900</td>
#       <td id="T_526eb_row0_col4" class="data row0 col4" >0.747900</td>
#       <td id="T_526eb_row0_col5" class="data row0 col5" >0.747900</td>
#     </tr>
#     <tr>
#       <th id="T_526eb_level0_row1" class="row_heading level0 row1" >ljl</th>
#       <th id="T_526eb_level1_row1" class="row_heading level1 row1" >CECRL</th>
#       <td id="T_526eb_row1_col0" class="data row1 col0" >0.636800</td>
#       <td id="T_526eb_row1_col1" class="data row1 col1" >0.628100</td>
#       <td id="T_526eb_row1_col2" class="data row1 col2" >0.680500</td>
#       <td id="T_526eb_row1_col3" class="data row1 col3" >0.636800</td>
#       <td id="T_526eb_row1_col4" class="data row1 col4" >0.605600</td>
#       <td id="T_526eb_row1_col5" class="data row1 col5" >0.636800</td>
#     </tr>
#     <tr>
#       <th id="T_526eb_level0_row2" class="row_heading level0 row2" >sentences</th>
#       <th id="T_526eb_level1_row2" class="row_heading level1 row2" >no-context</th>
#       <td id="T_526eb_row2_col0" class="data row2 col0" >0.631200</td>
#       <td id="T_526eb_row2_col1" class="data row2 col1" >0.627900</td>
#       <td id="T_526eb_row2_col2" class="data row2 col2" >0.650500</td>
#       <td id="T_526eb_row2_col3" class="data row2 col3" >0.631200</td>
#       <td id="T_526eb_row2_col4" class="data row2 col4" >0.631200</td>
#       <td id="T_526eb_row2_col5" class="data row2 col5" >0.631200</td>
#     </tr>
#     <tr>
#       <th id="T_526eb_level0_row3" class="row_heading level0 row3" >french-difficulty</th>
#       <th id="T_526eb_level1_row3" class="row_heading level1 row3" >CECRL</th>
#       <td id="T_526eb_row3_col0" class="data row3 col0" >0.512500</td>
#       <td id="T_526eb_row3_col1" class="data row3 col1" >0.515100</td>
#       <td id="T_526eb_row3_col2" class="data row3 col2" >0.521200</td>
#       <td id="T_526eb_row3_col3" class="data row3 col3" >0.512500</td>
#       <td id="T_526eb_row3_col4" class="data row3 col4" >0.512500</td>
#       <td id="T_526eb_row3_col5" class="data row3 col5" >0.512500</td>
#     </tr>
#     <tr>
#       <th id="T_526eb_level0_row4" class="row_heading level0 row4" >ljl</th>
#       <th id="T_526eb_level1_row4" class="row_heading level1 row4" >no-context</th>
#       <td id="T_526eb_row4_col0" class="data row4 col0" >0.472200</td>
#       <td id="T_526eb_row4_col1" class="data row4 col1" >0.337600</td>
#       <td id="T_526eb_row4_col2" class="data row4 col2" >0.473900</td>
#       <td id="T_526eb_row4_col3" class="data row4 col3" >0.472200</td>
#       <td id="T_526eb_row4_col4" class="data row4 col4" >0.355600</td>
#       <td id="T_526eb_row4_col5" class="data row4 col5" >0.472200</td>
#     </tr>
#     <tr>
#       <th id="T_526eb_level0_row5" class="row_heading level0 row5" >french-difficulty</th>
#       <th id="T_526eb_level1_row5" class="row_heading level1 row5" >no-context</th>
#       <td id="T_526eb_row5_col0" class="data row5 col0" >0.354200</td>
#       <td id="T_526eb_row5_col1" class="data row5 col1" >0.306300</td>
#       <td id="T_526eb_row5_col2" class="data row5 col2" >0.448000</td>
#       <td id="T_526eb_row5_col3" class="data row5 col3" >0.354200</td>
#       <td id="T_526eb_row5_col4" class="data row5 col4" >0.354200</td>
#       <td id="T_526eb_row5_col5" class="data row5 col5" >0.354200</td>
#     </tr>
#   </tbody>
# </table>
