# %% [markdown]
# # Create Figures for Paper
#
# Ce notebook permet de créer les figures du papier.

# %%
# ---------------------------- PREPARING NOTEBOOK ---------------------------- #
# Autoreload
# %load_ext autoreload
# %autoreload 2

# Random seed
import numpy as np
np.random.seed(42)

# External modules
import os
from IPython.display import display, Markdown, Latex, clear_output
from tqdm import notebook as tqdm

# Set global log level
import logging
logging.basicConfig(level=logging.INFO)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Define PWD as the current git repository
import git
repo = git.Repo('.', search_parent_directories=True)
pwd = repo.working_dir
os.chdir(pwd)

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### OpenAI Evaluation

# %%
import pandas as pd

# Load metrics
path = os.path.join(
    pwd, "results", "difficulty_estimation", "OpenAiEvaluation", "metrics.csv"
)
openai_classification_metrics = pd.read_csv(path)
openai_classification_metrics
# Out:
#               dataset context               model  accuracy  f1 (macro)  \
# 0           sentences   CECRL  gpt-3.5-turbo-1106  0.897917    0.896970
# 1           sentences   empty  gpt-3.5-turbo-1106  0.866667    0.864868
# 2           sentences   CECRL         davinci-002  0.814583    0.812253
# 3                 ljl   empty  gpt-3.5-turbo-1106  0.733656    0.745840
# 4                 ljl   CECRL  gpt-3.5-turbo-1106  0.723971    0.735612
# 5           sentences   empty         davinci-002  0.825000    0.619090
# 6           sentences   empty         babbage-002  0.812500    0.609588
# 7           sentences   CECRL         babbage-002  0.812500    0.608993
# 8   french-difficulty   CECRL  gpt-3.5-turbo-1106  0.498958    0.423531
# 9                 ljl   empty         davinci-002  0.585956    0.337429
# 10                ljl   CECRL         davinci-002  0.610169    0.312199
# 11  french-difficulty   empty  gpt-3.5-turbo-1106  0.485417    0.292785
# 12  french-difficulty   CECRL         babbage-002  0.485417    0.289870
# 13  french-difficulty   empty         davinci-002  0.469792    0.280508
# 14                ljl   CECRL         babbage-002  0.585956    0.261941
# 15  french-difficulty   CECRL         davinci-002  0.469792    0.254112
# 16                ljl   empty         babbage-002  0.612591    0.250579
# 17  french-difficulty   empty         babbage-002  0.438542    0.187762
#
#     f1 (micro)  precision (macro)  precision (micro)  recall (macro)  \
# 0     0.897917           0.897494           0.897917        0.897917
# 1     0.866667           0.866231           0.866667        0.866667
# 2     0.814583           0.811908           0.814583        0.814583
# 3     0.733656           0.749340           0.733656        0.746278
# 4     0.723971           0.756418           0.723971        0.725500
# 5     0.825000           0.622441           0.825000        0.618750
# 6     0.812500           0.612527           0.812500        0.609375
# 7     0.812500           0.610264           0.812500        0.609375
# 8     0.498958           0.428613           0.498958        0.427679
# 9     0.585956           0.347085           0.585956        0.331162
# 10    0.610169           0.319176           0.610169        0.310129
# 11    0.485417           0.298541           0.485417        0.291250
# 12    0.485417           0.297746           0.485417        0.291250
# 13    0.469792           0.287537           0.469792        0.281875
# 14    0.585956           0.266914           0.585956        0.259139
# 15    0.469792           0.256299           0.469792        0.256250
# 16    0.612591           0.262796           0.612591        0.243034
# 17    0.438542           0.189873           0.438542        0.187946
#
#     recall (micro)
# 0         0.897917
# 1         0.866667
# 2         0.814583
# 3         0.733656
# 4         0.723971
# 5         0.825000
# 6         0.812500
# 7         0.812500
# 8         0.498958
# 9         0.585956
# 10        0.610169
# 11        0.485417
# 12        0.485417
# 13        0.469792
# 14        0.585956
# 15        0.469792
# 16        0.612591
# 17        0.438542

# %% [markdown]
# ### Open-source Models Evaluation

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "bert_metrics.csv",
)
bert_classification_metrics = pd.read_csv(path)
bert_classification_metrics
# Out:
#           Unnamed: 0  accuracy        f1  precision_macro  precision_micro  \
# 0          sentences  0.822917  0.821201         0.826776         0.822917
# 1                ljl  0.624697  0.631121         0.626671         0.624697
# 2  french_difficulty  0.522917  0.512580         0.528225         0.522917
#
#    recall_macro  recall_micro
# 0      0.822917      0.822917
# 1      0.640783      0.624697
# 2      0.522917      0.522917

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "mistral_metrics.csv",
)
mistral_classification_metrics = pd.read_csv(path)
mistral_classification_metrics
# Out:
#              dataset     context  accuracy      f1  precision_macro  \
# 0          sentences       CECRL    0.7479  0.7347           0.7739
# 1                ljl       CECRL    0.6368  0.6281           0.6805
# 2          sentences  no-context    0.6312  0.6279           0.6505
# 3  french-difficulty       CECRL    0.5125  0.5151           0.5212
# 4                ljl  no-context    0.4722  0.3376           0.4739
# 5  french-difficulty  no-context    0.3542  0.3063           0.4480
#
#    precision_micro  recall_macro  recall_micro
# 0           0.7479        0.7479        0.7479
# 1           0.6368        0.6056        0.6368
# 2           0.6312        0.6312        0.6312
# 3           0.5125        0.5125        0.5125
# 4           0.4722        0.3556        0.4722
# 5           0.3542        0.3542        0.3542

# %% [markdown]
# ### Pairwise Mismatched Evaluation

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "readability_index_classification_metrics.csv",
)
readability_index_classification_metrics = pd.read_csv(path)
readability_index_classification_metrics
# Out:
#              dataset model  accuracy      f1  precision  recall
# 0                ljl   gfi    0.4504  0.4119     0.4692  0.4051
# 1                ljl  fkgl    0.4213  0.4064     0.4704  0.3913
# 2                ljl   ari    0.3995  0.3229     0.4462  0.3350
# 3  french-difficulty  fkgl    0.3458  0.3366     0.3386  0.3458
# 4          sentences   ari    0.3438  0.2797     0.2941  0.3438
# 5  french-difficulty   gfi    0.3417  0.3141     0.3230  0.3417
# 6  french-difficulty   ari    0.3417  0.3325     0.3340  0.3417
# 7          sentences  fkgl    0.3354  0.2856     0.2930  0.3354
# 8          sentences   gfi    0.3229  0.2786     0.2932  0.3229

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "readability_index_pairwise_mismatch.csv",
)
readability_index_pairwise_mismatch = pd.read_csv(path)
readability_index_pairwise_mismatch
# Out:
#              dataset model  pairwise_mismatch
# 0                ljl   gfi            44.0969
# 1                ljl   ari            47.0944
# 2                ljl  fkgl            54.5375
# 3          sentences   ari            88.2375
# 4          sentences  fkgl            99.3167
# 5          sentences   gfi           101.9583
# 6  french-difficulty   ari           111.5646
# 7  french-difficulty  fkgl           112.3771
# 8  french-difficulty   gfi           112.6271

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "bert_pairwise_mismatch.csv",
)
bert_pairwise_mismatch = pd.read_csv(path)
bert_pairwise_mismatch
# Out:
#           Unnamed: 0  Pairwise mismatch
# 0                ljl            13.9516
# 1          sentences            22.2125
# 2  french_difficulty            36.9812

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "openai_pairwise_mismatch.csv",
)
openai_pairwise_mismatch = pd.read_csv(path)
openai_pairwise_mismatch
# Out:
#               dataset context               model  pairwise_mismatch
# 0                 ljl   empty  gpt-3.5-turbo-1106             9.2736
# 1                 ljl   CECRL  gpt-3.5-turbo-1106            11.0605
# 2           sentences   CECRL  gpt-3.5-turbo-1106            13.1125
# 3           sentences   empty  gpt-3.5-turbo-1106            18.1083
# 4                 ljl   empty         babbage-002            18.3341
# 5                 ljl   CECRL         davinci-002            18.6925
# 6           sentences   empty         davinci-002            20.9042
# 7                 ljl   empty         davinci-002            21.0896
# 8           sentences   empty         babbage-002            21.2625
# 9                 ljl   CECRL         babbage-002            23.7482
# 10          sentences   CECRL         davinci-002            23.8250
# 11          sentences   CECRL         babbage-002            25.6417
# 12  french-difficulty   CECRL  gpt-3.5-turbo-1106            51.9792
# 13  french-difficulty   CECRL         babbage-002            60.9188
# 14  french-difficulty   empty  gpt-3.5-turbo-1106            61.1250
# 15  french-difficulty   CECRL         davinci-002            66.4396
# 16  french-difficulty   empty         davinci-002            76.5188
# 17  french-difficulty   empty         babbage-002            86.4021

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "mistral_pairwise_mismatch.csv",
)
mistral_pairwise_mismatch = pd.read_csv(path)
mistral_pairwise_mismatch
# Out:
#                      Unnamed: 0  Pairwise mismatch
# 0                     ljl_CECRL            13.6223
# 1                ljl_no-context            29.9855
# 2  french_difficulty_no-context            39.3771
# 3               sentences_CECRL            39.7625
# 4       french_difficulty_CECRL            48.4146
# 5          sentences_no-context            61.7542

# %% [markdown]
# ## Figures Creation

# %%
# Load metrics
metrics = {
    "readability_index_classification_metrics": readability_index_classification_metrics.copy(),
    "bert_classification_metrics": bert_classification_metrics.copy(),
    "mistral_classification_metrics": mistral_classification_metrics.copy(),
    "openai_classification_metrics": openai_classification_metrics.copy(),
    "readability_index_pairwise_mismatch": readability_index_pairwise_mismatch.copy(),
    "bert_pairwise_mismatch": bert_pairwise_mismatch.copy(),
    "mistral_pairwise_mismatch": mistral_pairwise_mismatch.copy(),
    "openai_pairwise_mismatch": openai_pairwise_mismatch.copy(),
}

# Format all dataframe to have the same columns in classification metrics
## Readability index
metrics["readability_index_classification_metrics"].columns = [
    "dataset",
    "model",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["readability_index_classification_metrics"]["context"] = "empty"
## CamemBERT
metrics["bert_classification_metrics"].drop(
    columns=["precision_macro", "recall_macro"], inplace=True
)
metrics["bert_classification_metrics"].columns = [
    "dataset",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["bert_classification_metrics"]["model"] = "CamemBERT"
metrics["bert_classification_metrics"]["context"] = "empty"
## Mistral
metrics["mistral_classification_metrics"].drop(
    columns=["precision_macro", "recall_macro"], inplace=True
)
metrics["mistral_classification_metrics"].columns = [
    "dataset",
    "context",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["mistral_classification_metrics"]["model"] = "Mistral-7B"
## OpenAI
metrics["openai_classification_metrics"].drop(
    columns=["f1 (micro)", "precision (micro)", "recall (micro)"], inplace=True
)
metrics["openai_classification_metrics"].columns = [
    "dataset",
    "context",
    "model",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]

# Format all dataframe to have the same columns in pairwise mismatch
## Readability index
metrics["readability_index_pairwise_mismatch"]["context"] = "empty"
metrics["readability_index_pairwise_mismatch"].columns = [
    "dataset",
    "model",
    "pairwise mismatch",
    "context",
]
## CamemBERT
metrics["bert_pairwise_mismatch"].columns = [
    "dataset",
    "pairwise mismatch",
]
metrics["bert_pairwise_mismatch"]["model"] = "CamemBERT"
metrics["bert_pairwise_mismatch"]["context"] = "empty"
## Mistral
metrics["mistral_pairwise_mismatch"].iloc[:, 0] = (
    metrics["mistral_pairwise_mismatch"]
    .iloc[:, 0]
    .str.replace("french_difficulty", "french-difficulty")
)
metrics["mistral_pairwise_mismatch"]["dataset"] = (
    metrics["mistral_pairwise_mismatch"].iloc[:, 0].apply(lambda x: x.split("_")[0])
)
metrics["mistral_pairwise_mismatch"]["context"] = (
    metrics["mistral_pairwise_mismatch"].iloc[:, 0].apply(lambda x: x.split("_")[1])
)
metrics["mistral_pairwise_mismatch"].drop(
    columns=[metrics["mistral_pairwise_mismatch"].columns[0]], inplace=True
)
metrics["mistral_pairwise_mismatch"].columns = [
    "pairwise mismatch",
    "dataset",
    "context",
]
metrics["mistral_pairwise_mismatch"]["model"] = "Mistral-7B"
## OpenAI
metrics["openai_pairwise_mismatch"].columns = [
    "dataset",
    "context",
    "model",
    "pairwise mismatch",
]

# Merge classification metrics and pairwise mismatch
merged_metrics = {}
for key, metric in metrics.items():
    table = "_".join(key.split("_")[:-2])
    if table not in merged_metrics.keys():
        merged_metrics[table] = metric.copy()
    else:
        merged_metrics[table] = merged_metrics[table].merge(
            metric, on=["dataset", "model", "context"]
        )

# Concatenate all metrics
concatenated_metrics = pd.concat(merged_metrics.values(), ignore_index=True)

# Replace "no-context" by "empty" and "french_difficulty" by "french-difficulty"
concatenated_metrics["context"] = concatenated_metrics["context"].replace(
    "no-context", "empty"
)
concatenated_metrics["dataset"] = concatenated_metrics["dataset"].replace(
    "french_difficulty", "french-difficulty"
)

# Reorder columns
concatenated_metrics = concatenated_metrics[
    [
        "model",
        "context",
        "dataset",
        "pairwise mismatch",
        "accuracy",
        "f1 (micro)",
        "precision (micro)",
        "recall (micro)",
    ]
]

# Remove "babbage-002" model
concatenated_metrics = concatenated_metrics[
    concatenated_metrics["model"] != "babbage-002"
]

# Capitalize model names
concatenated_metrics["model"] = concatenated_metrics["model"].apply(
    lambda x: x.replace("gpt", "GPT")
    .replace("bert", "BERT")
    .replace("mistral", "Mistral")
    .replace("davinci", "Davinci")
    .replace("gfi", "GFI")
    .replace("ari", "ARI")
    .replace("fkgl", "FKGL")
)

# Round all metrics to 2 decimals
concatenated_metrics = concatenated_metrics.round(2)

# Sort by pairwise mismatch
concatenated_metrics.sort_values(by=["pairwise mismatch"], inplace=True)

# Replace context
concatenated_metrics["context"] = (
    concatenated_metrics["context"].replace("empty", "-").replace("CECRL", "\checkmark")
)

# Split by dataset
datasets_metrics = {}
for dataset in concatenated_metrics["dataset"].unique():
    # Split by dataset
    datasets_metrics[dataset] = (
        concatenated_metrics[concatenated_metrics["dataset"] == dataset]
        .copy()
        .drop(columns=["dataset"])
    ).reset_index(drop=True)

    # Set multi-index from model and context
    datasets_metrics[dataset].set_index(["model", "context"], inplace=True)


for dataset, metric in datasets_metrics.items():
    display(Markdown(f"### {dataset}"))
    with pd.option_context("display.max_rows", None, "display.max_columns", None):
        display(metric)
# Out:
# ### ljl
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# GPT-3.5-turbo-1106 -                        9.27      0.73        0.75
#                    \checkmark              11.06      0.72        0.74
# Mistral-7B         \checkmark              13.62      0.64        0.63
# CamemBERT          -                       13.95      0.62        0.63
# Davinci-002        \checkmark              18.69      0.61        0.31
#                    -                       21.09      0.59        0.34
# Mistral-7B         -                       29.99      0.47        0.34
# GFI                -                       44.10      0.45        0.41
# ARI                -                       47.09      0.40        0.32
# FKGL               -                       54.54      0.42        0.41
#
#                                precision (micro)  recall (micro)
# model              context
# GPT-3.5-turbo-1106 -                        0.75            0.75
#                    \checkmark               0.76            0.73
# Mistral-7B         \checkmark               0.64            0.64
# CamemBERT          -                        0.62            0.62
# Davinci-002        \checkmark               0.32            0.31
#                    -                        0.35            0.33
# Mistral-7B         -                        0.47            0.47
# GFI                -                        0.47            0.41
# ARI                -                        0.45            0.34
# FKGL               -                        0.47            0.39
# ### sentences
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# GPT-3.5-turbo-1106 \checkmark              13.11      0.90        0.90
#                    -                       18.11      0.87        0.86
# Davinci-002        -                       20.90      0.82        0.62
# CamemBERT          -                       22.21      0.82        0.82
# Davinci-002        \checkmark              23.82      0.81        0.81
# Mistral-7B         \checkmark              39.76      0.75        0.73
#                    -                       61.75      0.63        0.63
# ARI                -                       88.24      0.34        0.28
# FKGL               -                       99.32      0.34        0.29
# GFI                -                      101.96      0.32        0.28
#
#                                precision (micro)  recall (micro)
# model              context
# GPT-3.5-turbo-1106 \checkmark               0.90            0.90
#                    -                        0.87            0.87
# Davinci-002        -                        0.62            0.62
# CamemBERT          -                        0.82            0.82
# Davinci-002        \checkmark               0.81            0.81
# Mistral-7B         \checkmark               0.75            0.75
#                    -                        0.63            0.63
# ARI                -                        0.29            0.34
# FKGL               -                        0.29            0.34
# GFI                -                        0.29            0.32
# ### french-difficulty
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# CamemBERT          -                       36.98      0.52        0.51
# Mistral-7B         -                       39.38      0.35        0.31
#                    \checkmark              48.41      0.51        0.52
# GPT-3.5-turbo-1106 \checkmark              51.98      0.50        0.42
#                    -                       61.12      0.49        0.29
# Davinci-002        \checkmark              66.44      0.47        0.25
#                    -                       76.52      0.47        0.28
# ARI                -                      111.56      0.34        0.33
# FKGL               -                      112.38      0.35        0.34
# GFI                -                      112.63      0.34        0.31
#
#                                precision (micro)  recall (micro)
# model              context
# CamemBERT          -                        0.52            0.52
# Mistral-7B         -                        0.35            0.35
#                    \checkmark               0.51            0.51
# GPT-3.5-turbo-1106 \checkmark               0.43            0.43
#                    -                        0.30            0.29
# Davinci-002        \checkmark               0.26            0.26
#                    -                        0.29            0.28
# ARI                -                        0.33            0.34
# FKGL               -                        0.34            0.35
# GFI                -                        0.32            0.34

# %% [markdown]
# ## Exporting as Latex

# %% [markdown]
# ### Tables

# %%
# Mute pandas warning
import warnings
import seaborn as sns

warnings.simplefilter(action="ignore", category=FutureWarning)


# Bold best results
def highlight_best(x):
    # Create empty dataframe
    df = pd.DataFrame("", index=x.index, columns=x.columns)

    # Bold min of pairwise mismatch
    df["pairwise mismatch"].loc[
        x["pairwise mismatch"].idxmin()
    ] += "font-weight: bold; color: #FF9999;"

    # Bold max of accuracy	f1 (micro)	precision (micro)	recall (micro)
    for metric in ["accuracy", "f1 (micro)", "precision (micro)", "recall (micro)"]:
        df[metric].loc[x[metric].idxmax()] += "font-weight: bold; color: #FF9999;"

    return df


for dataset_name, df in datasets_metrics.items():
    styled_df = (
        df.style.background_gradient(cmap=sns.light_palette("green", as_cmap=True))
        .background_gradient(
            cmap=sns.light_palette("green", as_cmap=True, reverse=True),
            subset=["pairwise mismatch"],
        )
        .apply(highlight_best, axis=None)
        .applymap_index(lambda v: "font-weight: bold;", axis="columns")
        .applymap_index(lambda v: "font-weight: bold;", axis="rows")
        .format(decimal=",", thousands=".", precision=2)
    )
    display(styled_df)
    path = os.path.join(pwd, "figures", "difficulty_estimation", f"{dataset_name}.tex")
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path))
    latex = styled_df.to_latex(
        caption=(f"Metrics for the {dataset_name} dataset"),
        clines="skip-last;data",
        convert_css=True,
        position_float="centering",
        multicol_align="|c|",
        hrules=True,
    )

    # Add \begin{adjustbox}{center}
    latex = latex.replace(
        "\\begin{tabular}", "\\begin{adjustbox}{center}\n\\begin{tabular}"
    ).replace("\\end{tabular}", "\\end{tabular}\n\\end{adjustbox}")

    # Add comment under the table
    latex = latex.replace(
        "\\end{adjustbox}",
        "\\end{adjustbox}\n\\begin{minipage}{12cm}\n\\vspace{0.1cm}\n\\hline\n\\vspace{0.1cm}\n\\begin{itemize}\n\\item The best results have been highlighted in bold and light red.\n\\item The color gradient is more intense for the best results.\n\\begin{itemize}\n\\item The smallest values for the \\textbf{pairwise mismatch} metric.\n\\item The largest values for the  \\textbf{accuracy}, \\textbf{f1}, \\textbf{precision} and \\textbf{recall} metrics.\n\\end{itemize}\n\\item The models are sorted by pairwise mismatch performance\n\n\item The column \\textit{context} indicates whether the model has been trained and evaluated with the context \\textit{CECRL} described above.\\end{itemize}\n\\end{minipage}",
    )

    # Force position of table
    latex = latex.replace("\\begin{table}", "\\begin{table}[!h]")

    print(latex)
# Out:
# <style type="text/css">
# #T_7e323_row0_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_7e323_row0_col1, #T_7e323_row0_col2, #T_7e323_row0_col4, #T_7e323_row1_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_7e323_row0_col3, #T_7e323_row1_col2 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_7e323_row1_col0 {
#   background-color: #e1eee1;
#   color: #000000;
#   background-color: #098509;
#   color: #f1f1f1;
# }
# #T_7e323_row1_col1 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_7e323_row1_col4 {
#   background-color: #0a850a;
#   color: #f1f1f1;
# }
# #T_7e323_row2_col0 {
#   background-color: #d4e8d4;
#   color: #000000;
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_7e323_row2_col1, #T_7e323_row2_col2, #T_7e323_row2_col3, #T_7e323_row3_col2 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_7e323_row2_col4 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# #T_7e323_row3_col0 {
#   background-color: #d3e7d3;
#   color: #000000;
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_7e323_row3_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_7e323_row3_col3 {
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_7e323_row3_col4 {
#   background-color: #45a245;
#   color: #f1f1f1;
# }
# #T_7e323_row4_col0 {
#   background-color: #badbba;
#   color: #000000;
#   background-color: #319831;
#   color: #f1f1f1;
# }
# #T_7e323_row4_col1 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_7e323_row4_col2, #T_7e323_row4_col3, #T_7e323_row4_col4, #T_7e323_row8_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_7e323_row5_col0 {
#   background-color: #aed5ae;
#   color: #000000;
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_7e323_row5_col1 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_7e323_row5_col2, #T_7e323_row5_col3, #T_7e323_row6_col2, #T_7e323_row8_col4 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_7e323_row5_col4 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_7e323_row6_col0 {
#   background-color: #7fbe7f;
#   color: #000000;
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_7e323_row6_col1 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_7e323_row6_col3, #T_7e323_row7_col3, #T_7e323_row9_col3 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_7e323_row6_col4 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_7e323_row7_col0 {
#   background-color: #369b36;
#   color: #f1f1f1;
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_7e323_row7_col1 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_7e323_row7_col2, #T_7e323_row7_col4, #T_7e323_row9_col2 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_7e323_row8_col0 {
#   background-color: #279327;
#   color: #f1f1f1;
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_7e323_row8_col2 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_7e323_row8_col3 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_7e323_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_7e323_row9_col1 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_7e323_row9_col4 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_7e323_level0_row0, #T_7e323_level1_row0, #T_7e323_level1_row1, #T_7e323_level0_row2, #T_7e323_level1_row2, #T_7e323_level0_row3, #T_7e323_level1_row3, #T_7e323_level0_row4, #T_7e323_level1_row4, #T_7e323_level1_row5, #T_7e323_level0_row6, #T_7e323_level1_row6, #T_7e323_level0_row7, #T_7e323_level1_row7, #T_7e323_level0_row8, #T_7e323_level1_row8, #T_7e323_level0_row9, #T_7e323_level1_row9 {
#   font-weight: bold;
# }
# #T_7e323_level0_col0, #T_7e323_level0_col1, #T_7e323_level0_col2, #T_7e323_level0_col3, #T_7e323_level0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_7e323">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e323_level0_col0" class="col_heading level0 col0" >pairwise mismatch</th>
#       <th id="T_7e323_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_7e323_level0_col2" class="col_heading level0 col2" >f1 (micro)</th>
#       <th id="T_7e323_level0_col3" class="col_heading level0 col3" >precision (micro)</th>
#       <th id="T_7e323_level0_col4" class="col_heading level0 col4" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e323_level0_row0" class="row_heading level0 row0" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_7e323_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_7e323_row0_col0" class="data row0 col0" >9,27</td>
#       <td id="T_7e323_row0_col1" class="data row0 col1" >0,73</td>
#       <td id="T_7e323_row0_col2" class="data row0 col2" >0,75</td>
#       <td id="T_7e323_row0_col3" class="data row0 col3" >0,75</td>
#       <td id="T_7e323_row0_col4" class="data row0 col4" >0,75</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level1_row1" class="row_heading level1 row1" >\checkmark</th>
#       <td id="T_7e323_row1_col0" class="data row1 col0" >11,06</td>
#       <td id="T_7e323_row1_col1" class="data row1 col1" >0,72</td>
#       <td id="T_7e323_row1_col2" class="data row1 col2" >0,74</td>
#       <td id="T_7e323_row1_col3" class="data row1 col3" >0,76</td>
#       <td id="T_7e323_row1_col4" class="data row1 col4" >0,73</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level0_row2" class="row_heading level0 row2" >Mistral-7B</th>
#       <th id="T_7e323_level1_row2" class="row_heading level1 row2" >\checkmark</th>
#       <td id="T_7e323_row2_col0" class="data row2 col0" >13,62</td>
#       <td id="T_7e323_row2_col1" class="data row2 col1" >0,64</td>
#       <td id="T_7e323_row2_col2" class="data row2 col2" >0,63</td>
#       <td id="T_7e323_row2_col3" class="data row2 col3" >0,64</td>
#       <td id="T_7e323_row2_col4" class="data row2 col4" >0,64</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level0_row3" class="row_heading level0 row3" >CamemBERT</th>
#       <th id="T_7e323_level1_row3" class="row_heading level1 row3" >-</th>
#       <td id="T_7e323_row3_col0" class="data row3 col0" >13,95</td>
#       <td id="T_7e323_row3_col1" class="data row3 col1" >0,62</td>
#       <td id="T_7e323_row3_col2" class="data row3 col2" >0,63</td>
#       <td id="T_7e323_row3_col3" class="data row3 col3" >0,62</td>
#       <td id="T_7e323_row3_col4" class="data row3 col4" >0,62</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level0_row4" class="row_heading level0 row4" rowspan="2">Davinci-002</th>
#       <th id="T_7e323_level1_row4" class="row_heading level1 row4" >\checkmark</th>
#       <td id="T_7e323_row4_col0" class="data row4 col0" >18,69</td>
#       <td id="T_7e323_row4_col1" class="data row4 col1" >0,61</td>
#       <td id="T_7e323_row4_col2" class="data row4 col2" >0,31</td>
#       <td id="T_7e323_row4_col3" class="data row4 col3" >0,32</td>
#       <td id="T_7e323_row4_col4" class="data row4 col4" >0,31</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level1_row5" class="row_heading level1 row5" >-</th>
#       <td id="T_7e323_row5_col0" class="data row5 col0" >21,09</td>
#       <td id="T_7e323_row5_col1" class="data row5 col1" >0,59</td>
#       <td id="T_7e323_row5_col2" class="data row5 col2" >0,34</td>
#       <td id="T_7e323_row5_col3" class="data row5 col3" >0,35</td>
#       <td id="T_7e323_row5_col4" class="data row5 col4" >0,33</td>
#     </tr>
#     <tr>
#       <th id="T_7e323_level0_row6" class="row_heading level0 row6" >Mistral-7B</th>
#       <th id="T_7e323_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_7e323_row6_col0" class="data row6 col0" >29,99</td>
#       <td id="T_7e323_row6_col1" class="data row6 col1" >0,47</td>
#       <td id="T_7e323_row
# \begin{table}[!h]
# \centering
# \caption{Metrics for the ljl dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrrr}
# \toprule
#  &  & \bfseries pairwise mismatch & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 9,27 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,73 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,75 & {\cellcolor[HTML]{058205}} \color[HTML]{F1F1F1} 0,75 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,75 \\
# \bfseries  & \bfseries \checkmark & {\cellcolor[HTML]{E1EEE1}} \color[HTML]{000000} {\cellcolor[HTML]{098509}} \color[HTML]{F1F1F1} 11,06 & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0,72 & {\cellcolor[HTML]{058205}} \color[HTML]{F1F1F1} 0,74 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,76 & {\cellcolor[HTML]{0A850A}} \color[HTML]{F1F1F1} 0,73 \\
# \cline{1-7}
# \bfseries Mistral-7B & \bfseries \checkmark & {\cellcolor[HTML]{D4E8D4}} \color[HTML]{000000} {\cellcolor[HTML]{168B16}} \color[HTML]{F1F1F1} 13,62 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0,64 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0,63 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0,64 & {\cellcolor[HTML]{3A9C3A}} \color[HTML]{F1F1F1} 0,64 \\
# \cline{1-7}
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{D3E7D3}} \color[HTML]{000000} {\cellcolor[HTML]{188C18}} \color[HTML]{F1F1F1} 13,95 & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0,62 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0,63 & {\cellcolor[HTML]{4BA54A}} \color[HTML]{F1F1F1} 0,62 & {\cellcolor[HTML]{45A245}} \color[HTML]{F1F1F1} 0,62 \\
# \cline{1-7}
# \multirow[c]{2}{*}{\bfseries Davinci-002} & \bfseries \checkmark & {\cellcolor[HTML]{BADBBA}} \color[HTML]{000000} {\cellcolor[HTML]{319831}} \color[HTML]{F1F1F1} 18,69 & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0,61 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,31 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,31 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{AED5AE}} \color[HTML]{000000} {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 21,09 & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0,59 & {\cellcolor[HTML]{DBEBDB}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{DBEBDB}} \color[HTML]{000000} 0,35 & {\cellcolor[HTML]{E0EEE0}} \color[HTML]{000000} 0,33 \\
# \cline{1-7}
# \bfseries Mistral-7B & \bfseries - & {\cellcolor[HTML]{7FBE7F}} \color[HTML]{000000} {\cellcolor[HTML]{6CB56C}} \color[HTML]{F1F1F1} 29,99 & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0,47 & {\cellcolor[HTML]{DBEBDB}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{9BCC9B}} \color[HTML]{000000} 0,47 & {\cellcolor[HTML]{95C995}} \color[HTML]{000000} 0,47 \\
# \cline{1-7}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{369B36}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{B4D8B4}} \color[HTML]{000000} 44,10 & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0,45 & {\cellcolor[HTML]{B5D9B5}} \color[HTML]{000000} 0,41 & {\cellcolor[HTML]{9BCC9B}} \color[HTML]{000000} 0,47 & {\cellcolor[HTML]{B5D9B5}} \color[HTML]{000000} 0,41 \\
# \cline{1-7}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{C4E0C4}} \color[HTML]{000000} 47,09 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,40 & {\cellcolor[HTML]{E6F1E6}} \color[HTML]{000000} 0,32 & {\cellcolor[HTML]{A6D1A6}} \color[HTML]{000000} 0,45 & {\cellcolor[HTML]{DBEBDB}} \color[HTML]{000000} 0,34 \\
# \cline{1-7}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 54,54 & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0,42 & {\cellcolor[HTML]{B5D9B5}} \color[HTML]{000000} 0,41 & {\cellcolor[HTML]{9BCC9B}} \color[HTML]{000000} 0,47 & {\cellcolor[HTML]{C0DEC0}} \color[HTML]{000000} 0,39 \\
# \cline{1-7}
# \bottomrule
# \end{tabular}
# \end{adjustbox}
# \begin{minipage}{12cm}
# \vspace{0.1cm}
# \hline
# \vspace{0.1cm}
# \begin{itemize}
# \item The best results have been highlighted in bold and light red.
# \item The color gradient is more intense for the best results.
# \begin{itemize}
# \item The smallest values for the \textbf{pairwise mismatch} metric.
# \item The largest values for the  \textbf{accuracy}, \textbf{f1}, \textbf{precision} and \textbf{recall} metrics.
# \end{itemize}
# \item The models are sorted by pairwise mismatch performance
#
# \item The column \textit{context} indicates whether the model has been trained and evaluated with the context \textit{CECRL} described above.\end{itemize}
# \end{minipage}
# \end{table}
# <style type="text/css">
# #T_07dbc_row0_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_07dbc_row0_col1, #T_07dbc_row0_col2, #T_07dbc_row0_col3, #T_07dbc_row0_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_07dbc_row1_col0 {
#   background-color: #deedde;
#   color: #000000;
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_07dbc_row1_col1, #T_07dbc_row1_col4 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_07dbc_row1_col2 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_07dbc_row1_col3 {
#   background-color: #0b850b;
#   color: #f1f1f1;
# }
# #T_07dbc_row2_col0 {
#   background-color: #d6e9d6;
#   color: #000000;
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_07dbc_row2_col1, #T_07dbc_row3_col1, #T_07dbc_row3_col4 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_07dbc_row2_col2 {
#   background-color: #6ab46a;
#   color: #f1f1f1;
# }
# #T_07dbc_row2_col3 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_07dbc_row2_col4 {
#   background-color: #71b771;
#   color: #f1f1f1;
# }
# #T_07dbc_row3_col0 {
#   background-color: #d3e7d3;
#   color: #000000;
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_07dbc_row3_col2, #T_07dbc_row3_col3 {
#   background-color: #1e8f1e;
#   color: #f1f1f1;
# }
# #T_07dbc_row4_col0 {
#   background-color: #cfe5cf;
#   color: #000000;
#   background-color: #1c8e1c;
#   color: #f1f1f1;
# }
# #T_07dbc_row4_col1, #T_07dbc_row4_col4 {
#   background-color: #249224;
#   color: #f1f1f1;
# }
# #T_07dbc_row4_col2, #T_07dbc_row4_col3 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_07dbc_row5_col0 {
#   background-color: #a5d1a5;
#   color: #000000;
#   background-color: #46a246;
#   color: #f1f1f1;
# }
# #T_07dbc_row5_col1, #T_07dbc_row5_col4 {
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_07dbc_row5_col2 {
#   background-color: #40a040;
#   color: #f1f1f1;
# }
# #T_07dbc_row5_col3 {
#   background-color: #399c39;
#   color: #f1f1f1;
# }
# #T_07dbc_row6_col0 {
#   background-color: #6ab46a;
#   color: #f1f1f1;
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_07dbc_row6_col1, #T_07dbc_row6_col4 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_07dbc_row6_col2 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_07dbc_row6_col3 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_07dbc_row7_col0 {
#   background-color: #249224;
#   color: #f1f1f1;
#   background-color: #c7e1c7;
#   color: #000000;
# }
# #T_07dbc_row7_col1, #T_07dbc_row7_col4, #T_07dbc_row8_col1, #T_07dbc_row8_col4 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_07dbc_row7_col2, #T_07dbc_row7_col3, #T_07dbc_row8_col3, #T_07dbc_row9_col1, #T_07dbc_row9_col2, #T_07dbc_row9_col3, #T_07dbc_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_07dbc_row8_col0 {
#   background-color: #068306;
#   color: #f1f1f1;
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_07dbc_row8_col2 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_07dbc_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_07dbc_level0_row0, #T_07dbc_level1_row0, #T_07dbc_level1_row1, #T_07dbc_level0_row2, #T_07dbc_level1_row2, #T_07dbc_level0_row3, #T_07dbc_level1_row3, #T_07dbc_level0_row4, #T_07dbc_level1_row4, #T_07dbc_level0_row5, #T_07dbc_level1_row5, #T_07dbc_level1_row6, #T_07dbc_level0_row7, #T_07dbc_level1_row7, #T_07dbc_level0_row8, #T_07dbc_level1_row8, #T_07dbc_level0_row9, #T_07dbc_level1_row9 {
#   font-weight: bold;
# }
# #T_07dbc_level0_col0, #T_07dbc_level0_col1, #T_07dbc_level0_col2, #T_07dbc_level0_col3, #T_07dbc_level0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_07dbc">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07dbc_level0_col0" class="col_heading level0 col0" >pairwise mismatch</th>
#       <th id="T_07dbc_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_07dbc_level0_col2" class="col_heading level0 col2" >f1 (micro)</th>
#       <th id="T_07dbc_level0_col3" class="col_heading level0 col3" >precision (micro)</th>
#       <th id="T_07dbc_level0_col4" class="col_heading level0 col4" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07dbc_level0_row0" class="row_heading level0 row0" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_07dbc_level1_row0" class="row_heading level1 row0" >\checkmark</th>
#       <td id="T_07dbc_row0_col0" class="data row0 col0" >13,11</td>
#       <td id="T_07dbc_row0_col1" class="data row0 col1" >0,90</td>
#       <td id="T_07dbc_row0_col2" class="data row0 col2" >0,90</td>
#       <td id="T_07dbc_row0_col3" class="data row0 col3" >0,90</td>
#       <td id="T_07dbc_row0_col4" class="data row0 col4" >0,90</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_07dbc_row1_col0" class="data row1 col0" >18,11</td>
#       <td id="T_07dbc_row1_col1" class="data row1 col1" >0,87</td>
#       <td id="T_07dbc_row1_col2" class="data row1 col2" >0,86</td>
#       <td id="T_07dbc_row1_col3" class="data row1 col3" >0,87</td>
#       <td id="T_07dbc_row1_col4" class="data row1 col4" >0,87</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level0_row2" class="row_heading level0 row2" >Davinci-002</th>
#       <th id="T_07dbc_level1_row2" class="row_heading level1 row2" >-</th>
#       <td id="T_07dbc_row2_col0" class="data row2 col0" >20,90</td>
#       <td id="T_07dbc_row2_col1" class="data row2 col1" >0,82</td>
#       <td id="T_07dbc_row2_col2" class="data row2 col2" >0,62</td>
#       <td id="T_07dbc_row2_col3" class="data row2 col3" >0,62</td>
#       <td id="T_07dbc_row2_col4" class="data row2 col4" >0,62</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level0_row3" class="row_heading level0 row3" >CamemBERT</th>
#       <th id="T_07dbc_level1_row3" class="row_heading level1 row3" >-</th>
#       <td id="T_07dbc_row3_col0" class="data row3 col0" >22,21</td>
#       <td id="T_07dbc_row3_col1" class="data row3 col1" >0,82</td>
#       <td id="T_07dbc_row3_col2" class="data row3 col2" >0,82</td>
#       <td id="T_07dbc_row3_col3" class="data row3 col3" >0,82</td>
#       <td id="T_07dbc_row3_col4" class="data row3 col4" >0,82</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level0_row4" class="row_heading level0 row4" >Davinci-002</th>
#       <th id="T_07dbc_level1_row4" class="row_heading level1 row4" >\checkmark</th>
#       <td id="T_07dbc_row4_col0" class="data row4 col0" >23,82</td>
#       <td id="T_07dbc_row4_col1" class="data row4 col1" >0,81</td>
#       <td id="T_07dbc_row4_col2" class="data row4 col2" >0,81</td>
#       <td id="T_07dbc_row4_col3" class="data row4 col3" >0,81</td>
#       <td id="T_07dbc_row4_col4" class="data row4 col4" >0,81</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level0_row5" class="row_heading level0 row5" rowspan="2">Mistral-7B</th>
#       <th id="T_07dbc_level1_row5" class="row_heading level1 row5" >\checkmark</th>
#       <td id="T_07dbc_row5_col0" class="data row5 col0" >39,76</td>
#       <td id="T_07dbc_row5_col1" class="data row5 col1" >0,75</td>
#       <td id="T_07dbc_row5_col2" class="data row5 col2" >0,73</td>
#       <td id="T_07dbc_row5_col3" class="data row5 col3" >0,75</td>
#       <td id="T_07dbc_row5_col4" class="data row5 col4" >0,75</td>
#     </tr>
#     <tr>
#       <th id="T_07dbc_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_07dbc_row6_col0" class="data row6 col0" >61,75</td>
#       <td id="T_07dbc_row6_col1" class="data row6 col1" >0,63</td>
#       <td id="T_07dbc_row6_col2" class="data row6 col2" >0,63</td>
#       <td id="T_07dbc_row6_col3" class="data row6 col3" >0,63</td>
#       <td id="T_07dbc_row6_col4" class=
# \begin{table}[!h]
# \centering
# \caption{Metrics for the sentences dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrrr}
# \toprule
#  &  & \bfseries pairwise mismatch & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries \checkmark & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 13,11 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,90 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 18,11 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0,87 & {\cellcolor[HTML]{0F870F}} \color[HTML]{F1F1F1} 0,86 & {\cellcolor[HTML]{0B850B}} \color[HTML]{F1F1F1} 0,87 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0,87 \\
# \cline{1-7}
# \bfseries Davinci-002 & \bfseries - & {\cellcolor[HTML]{D6E9D6}} \color[HTML]{000000} {\cellcolor[HTML]{148A14}} \color[HTML]{F1F1F1} 20,90 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0,82 & {\cellcolor[HTML]{6AB46A}} \color[HTML]{F1F1F1} 0,62 & {\cellcolor[HTML]{6CB56C}} \color[HTML]{F1F1F1} 0,62 & {\cellcolor[HTML]{71B771}} \color[HTML]{F1F1F1} 0,62 \\
# \cline{1-7}
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{D3E7D3}} \color[HTML]{000000} {\cellcolor[HTML]{188C18}} \color[HTML]{F1F1F1} 22,21 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0,82 & {\cellcolor[HTML]{1E8F1E}} \color[HTML]{F1F1F1} 0,82 & {\cellcolor[HTML]{1E8F1E}} \color[HTML]{F1F1F1} 0,82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0,82 \\
# \cline{1-7}
# \bfseries Davinci-002 & \bfseries \checkmark & {\cellcolor[HTML]{CFE5CF}} \color[HTML]{000000} {\cellcolor[HTML]{1C8E1C}} \color[HTML]{F1F1F1} 23,82 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0,81 & {\cellcolor[HTML]{229122}} \color[HTML]{F1F1F1} 0,81 & {\cellcolor[HTML]{229122}} \color[HTML]{F1F1F1} 0,81 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0,81 \\
# \cline{1-7}
# \multirow[c]{2}{*}{\bfseries Mistral-7B} & \bfseries \checkmark & {\cellcolor[HTML]{A5D1A5}} \color[HTML]{000000} {\cellcolor[HTML]{46A246}} \color[HTML]{F1F1F1} 39,76 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0,75 & {\cellcolor[HTML]{40A040}} \color[HTML]{F1F1F1} 0,73 & {\cellcolor[HTML]{399C39}} \color[HTML]{F1F1F1} 0,75 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0,75 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{6AB46A}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{81BF81}} \color[HTML]{000000} 61,75 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0,63 & {\cellcolor[HTML]{66B266}} \color[HTML]{F1F1F1} 0,63 & {\cellcolor[HTML]{68B368}} \color[HTML]{F1F1F1} 0,63 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0,63 \\
# \cline{1-7}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{C7E1C7}} \color[HTML]{000000} 88,24 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,28 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0,34 \\
# \cline{1-7}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{E4F0E4}} \color[HTML]{000000} 99,32 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{E7F1E7}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0,34 \\
# \cline{1-7}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 101,96 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,28 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,32 \\
# \cline{1-7}
# \bottomrule
# \end{tabular}
# \end{adjustbox}
# \begin{minipage}{12cm}
# \vspace{0.1cm}
# \hline
# \vspace{0.1cm}
# \begin{itemize}
# \item The best results have been highlighted in bold and light red.
# \item The color gradient is more intense for the best results.
# \begin{itemize}
# \item The smallest values for the \textbf{pairwise mismatch} metric.
# \item The largest values for the  \textbf{accuracy}, \textbf{f1}, \textbf{precision} and \textbf{recall} metrics.
# \end{itemize}
# \item The models are sorted by pairwise mismatch performance
#
# \item The column \textit{context} indicates whether the model has been trained and evaluated with the context \textit{CECRL} described above.\end{itemize}
# \end{minipage}
# \end{table}
# <style type="text/css">
# #T_6dcaa_row0_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_6dcaa_row0_col1, #T_6dcaa_row0_col3, #T_6dcaa_row0_col4, #T_6dcaa_row2_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_6dcaa_row0_col2, #T_6dcaa_row2_col3, #T_6dcaa_row2_col4 {
#   background-color: #088408;
#   color: #f1f1f1;
# }
# #T_6dcaa_row1_col0 {
#   background-color: #e3efe3;
#   color: #000000;
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_6dcaa_row1_col1, #T_6dcaa_row8_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_6dcaa_row1_col2, #T_6dcaa_row9_col2 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_6dcaa_row1_col3, #T_6dcaa_row1_col4, #T_6dcaa_row8_col4 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_6dcaa_row2_col0 {
#   background-color: #c8e2c8;
#   color: #000000;
#   background-color: #239123;
#   color: #f1f1f1;
# }
# #T_6dcaa_row2_col1 {
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_6dcaa_row3_col0 {
#   background-color: #bddcbd;
#   color: #000000;
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# #T_6dcaa_row3_col1 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_6dcaa_row3_col2 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_6dcaa_row3_col3, #T_6dcaa_row3_col4 {
#   background-color: #51a851;
#   color: #f1f1f1;
# }
# #T_6dcaa_row4_col0 {
#   background-color: #a0cea0;
#   color: #000000;
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_6dcaa_row4_col1 {
#   background-color: #279327;
#   color: #f1f1f1;
# }
# #T_6dcaa_row4_col2 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_6dcaa_row4_col3 {
#   background-color: #c7e1c7;
#   color: #000000;
# }
# #T_6dcaa_row4_col4, #T_6dcaa_row6_col3 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_6dcaa_row5_col0 {
#   background-color: #8fc68f;
#   color: #000000;
#   background-color: #5bad5b;
#   color: #f1f1f1;
# }
# #T_6dcaa_row5_col1, #T_6dcaa_row6_col1 {
#   background-color: #41a041;
#   color: #f1f1f1;
# }
# #T_6dcaa_row5_col2, #T_6dcaa_row5_col3, #T_6dcaa_row5_col4, #T_6dcaa_row7_col1, #T_6dcaa_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_6dcaa_row6_col0 {
#   background-color: #70b770;
#   color: #f1f1f1;
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_6dcaa_row6_col2 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_6dcaa_row6_col4 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_6dcaa_row7_col0 {
#   background-color: #038103;
#   color: #f1f1f1;
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_6dcaa_row7_col2 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_6dcaa_row7_col3 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_6dcaa_row7_col4, #T_6dcaa_row8_col3, #T_6dcaa_row9_col4 {
#   background-color: #a3d0a3;
#   color: #000000;
# }
# #T_6dcaa_row8_col0, #T_6dcaa_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_6dcaa_row8_col2 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_6dcaa_row9_col3 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_6dcaa_level0_row0, #T_6dcaa_level1_row0, #T_6dcaa_level0_row1, #T_6dcaa_level1_row1, #T_6dcaa_level1_row2, #T_6dcaa_level0_row3, #T_6dcaa_level1_row3, #T_6dcaa_level1_row4, #T_6dcaa_level0_row5, #T_6dcaa_level1_row5, #T_6dcaa_level1_row6, #T_6dcaa_level0_row7, #T_6dcaa_level1_row7, #T_6dcaa_level0_row8, #T_6dcaa_level1_row8, #T_6dcaa_level0_row9, #T_6dcaa_level1_row9 {
#   font-weight: bold;
# }
# #T_6dcaa_level0_col0, #T_6dcaa_level0_col1, #T_6dcaa_level0_col2, #T_6dcaa_level0_col3, #T_6dcaa_level0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6dcaa">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dcaa_level0_col0" class="col_heading level0 col0" >pairwise mismatch</th>
#       <th id="T_6dcaa_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_6dcaa_level0_col2" class="col_heading level0 col2" >f1 (micro)</th>
#       <th id="T_6dcaa_level0_col3" class="col_heading level0 col3" >precision (micro)</th>
#       <th id="T_6dcaa_level0_col4" class="col_heading level0 col4" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dcaa_level0_row0" class="row_heading level0 row0" >CamemBERT</th>
#       <th id="T_6dcaa_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_6dcaa_row0_col0" class="data row0 col0" >36,98</td>
#       <td id="T_6dcaa_row0_col1" class="data row0 col1" >0,52</td>
#       <td id="T_6dcaa_row0_col2" class="data row0 col2" >0,51</td>
#       <td id="T_6dcaa_row0_col3" class="data row0 col3" >0,52</td>
#       <td id="T_6dcaa_row0_col4" class="data row0 col4" >0,52</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level0_row1" class="row_heading level0 row1" rowspan="2">Mistral-7B</th>
#       <th id="T_6dcaa_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_6dcaa_row1_col0" class="data row1 col0" >39,38</td>
#       <td id="T_6dcaa_row1_col1" class="data row1 col1" >0,35</td>
#       <td id="T_6dcaa_row1_col2" class="data row1 col2" >0,31</td>
#       <td id="T_6dcaa_row1_col3" class="data row1 col3" >0,35</td>
#       <td id="T_6dcaa_row1_col4" class="data row1 col4" >0,35</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level1_row2" class="row_heading level1 row2" >\checkmark</th>
#       <td id="T_6dcaa_row2_col0" class="data row2 col0" >48,41</td>
#       <td id="T_6dcaa_row2_col1" class="data row2 col1" >0,51</td>
#       <td id="T_6dcaa_row2_col2" class="data row2 col2" >0,52</td>
#       <td id="T_6dcaa_row2_col3" class="data row2 col3" >0,51</td>
#       <td id="T_6dcaa_row2_col4" class="data row2 col4" >0,51</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level0_row3" class="row_heading level0 row3" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_6dcaa_level1_row3" class="row_heading level1 row3" >\checkmark</th>
#       <td id="T_6dcaa_row3_col0" class="data row3 col0" >51,98</td>
#       <td id="T_6dcaa_row3_col1" class="data row3 col1" >0,50</td>
#       <td id="T_6dcaa_row3_col2" class="data row3 col2" >0,42</td>
#       <td id="T_6dcaa_row3_col3" class="data row3 col3" >0,43</td>
#       <td id="T_6dcaa_row3_col4" class="data row3 col4" >0,43</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level1_row4" class="row_heading level1 row4" >-</th>
#       <td id="T_6dcaa_row4_col0" class="data row4 col0" >61,12</td>
#       <td id="T_6dcaa_row4_col1" class="data row4 col1" >0,49</td>
#       <td id="T_6dcaa_row4_col2" class="data row4 col2" >0,29</td>
#       <td id="T_6dcaa_row4_col3" class="data row4 col3" >0,30</td>
#       <td id="T_6dcaa_row4_col4" class="data row4 col4" >0,29</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level0_row5" class="row_heading level0 row5" rowspan="2">Davinci-002</th>
#       <th id="T_6dcaa_level1_row5" class="row_heading level1 row5" >\checkmark</th>
#       <td id="T_6dcaa_row5_col0" class="data row5 col0" >66,44</td>
#       <td id="T_6dcaa_row5_col1" class="data row5 col1" >0,47</td>
#       <td id="T_6dcaa_row5_col2" class="data row5 col2" >0,25</td>
#       <td id="T_6dcaa_row5_col3" class="data row5 col3" >0,26</td>
#       <td id="T_6dcaa_row5_col4" class="data row5 col4" >0,26</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_6dcaa_row6_col0" class="data row6 col0" >76,52</td>
#       <td id="T_6dcaa_row6_col1" class="data row6 col1" >0,47</td>
#       <td id="T_6dcaa_row6_col2" class="data row6 col2" >0,28</td>
#       <td id="T_6dcaa_row6_col3" class="data row6 col3" >0,29</td>
#       <td id="T_6dcaa_row6_col4" class="data row6 col4" >0,28</td>
#     </tr>
#     <tr>
#       <th id="T_6dcaa_level0_row7" class="row_
# \begin{table}[!h]
# \centering
# \caption{Metrics for the french-difficulty dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrrr}
# \toprule
#  &  & \bfseries pairwise mismatch & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  &  \\
# \midrule
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 36,98 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,52 & {\cellcolor[HTML]{088408}} \color[HTML]{F1F1F1} 0,51 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,52 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,52 \\
# \cline{1-7}
# \multirow[c]{2}{*}{\bfseries Mistral-7B} & \bfseries - & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} {\cellcolor[HTML]{078407}} \color[HTML]{F1F1F1} 39,38 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0,35 & {\cellcolor[HTML]{B7DAB7}} \color[HTML]{000000} 0,31 & {\cellcolor[HTML]{9ACB9A}} \color[HTML]{000000} 0,35 & {\cellcolor[HTML]{9ACB9A}} \color[HTML]{000000} 0,35 \\
# \bfseries  & \bfseries \checkmark & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} {\cellcolor[HTML]{239123}} \color[HTML]{F1F1F1} 48,41 & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0,51 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0,52 & {\cellcolor[HTML]{088408}} \color[HTML]{F1F1F1} 0,51 & {\cellcolor[HTML]{088408}} \color[HTML]{F1F1F1} 0,51 \\
# \cline{1-7}
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries \checkmark & {\cellcolor[HTML]{BDDCBD}} \color[HTML]{000000} {\cellcolor[HTML]{2E972E}} \color[HTML]{F1F1F1} 51,98 & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0,50 & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0,42 & {\cellcolor[HTML]{51A851}} \color[HTML]{F1F1F1} 0,43 & {\cellcolor[HTML]{51A851}} \color[HTML]{F1F1F1} 0,43 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{A0CEA0}} \color[HTML]{000000} {\cellcolor[HTML]{4BA54A}} \color[HTML]{F1F1F1} 61,12 & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0,49 & {\cellcolor[HTML]{C9E2C8}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{C7E1C7}} \color[HTML]{000000} 0,30 & {\cellcolor[HTML]{D0E6D0}} \color[HTML]{000000} 0,29 \\
# \cline{1-7}
# \multirow[c]{2}{*}{\bfseries Davinci-002} & \bfseries \checkmark & {\cellcolor[HTML]{8FC68F}} \color[HTML]{000000} {\cellcolor[HTML]{5BAD5B}} \color[HTML]{F1F1F1} 66,44 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0,47 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,25 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,26 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,26 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{70B770}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{7ABC7A}} \color[HTML]{000000} 76,52 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0,47 & {\cellcolor[HTML]{D1E6D1}} \color[HTML]{000000} 0,28 & {\cellcolor[HTML]{D0E6D0}} \color[HTML]{000000} 0,29 & {\cellcolor[HTML]{D9EAD9}} \color[HTML]{000000} 0,28 \\
# \cline{1-7}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{038103}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{E8F2E8}} \color[HTML]{000000} 111,56 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{A6D1A6}} \color[HTML]{000000} 0,33 & {\cellcolor[HTML]{ACD4AC}} \color[HTML]{000000} 0,33 & {\cellcolor[HTML]{A3D0A3}} \color[HTML]{000000} 0,34 \\
# \cline{1-7}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 112,38 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0,35 & {\cellcolor[HTML]{9CCD9C}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{A3D0A3}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{9ACB9A}} \color[HTML]{000000} 0,35 \\
# \cline{1-7}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 112,63 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0,34 & {\cellcolor[HTML]{B7DAB7}} \color[HTML]{000000} 0,31 & {\cellcolor[HTML]{B4D8B4}} \color[HTML]{000000} 0,32 & {\cellcolor[HTML]{A3D0A3}} \color[HTML]{000000} 0,34 \\
# \cline{1-7}
# \bottomrule
# \end{tabular}
# \end{adjustbox}
# \begin{minipage}{12cm}
# \vspace{0.1cm}
# \hline
# \vspace{0.1cm}
# \begin{itemize}
# \item The best results have been highlighted in bold and light red.
# \item The color gradient is more intense for the best results.
# \begin{itemize}
# \item The smallest values for the \textbf{pairwise mismatch} metric.
# \item The largest values for the  \textbf{accuracy}, \textbf{f1}, \textbf{precision} and \textbf{recall} metrics.
# \end{itemize}
# \item The models are sorted by pairwise mismatch performance
#
# \item The column \textit{context} indicates whether the model has been trained and evaluated with the context \textit{CECRL} described above.\end{itemize}
# \end{minipage}
# \end{table}

# %% [markdown]
# ### Figures

# %%
from matplotlib import pyplot as plt
import matplotlib

matplotlib.use("pgf")
matplotlib.rcParams.update(
    {
        "pgf.texsystem": "pdflatex",
        "font.family": "serif",
        "text.usetex": True,
        "pgf.rcfonts": False,
        "font.size": 10,
    }
)

# Bar plot of accuracy one bar per model and context on each dataset
df = concatenated_metrics.copy()
# Create model + context column
df["model + context"] = df["model"] + df["context"].replace("-", "").replace(
    "\checkmark", " + CECRL"
)
plt.figure()
barplot = sns.barplot(
    x="dataset",
    y="accuracy",
    hue="model + context",
    data=df,
    palette=sns.color_palette(
        [
            "#6baed6",
            "#3182bd",
            "#e6550d",
            "yellow",
            "#756bb1",
            "#9e9ac8",
            "#fd8d3c",
            "#31a354",
            "#74c476",
            "#a1d99b",
        ]
    ),
    ci=None,
)

# Itérer sur les barres du graphique et ajouter le texte à l'intérieur de chaque barre.
for p in barplot.patches:
    if p.get_height() > 0.0:
        barplot.annotate(
            "{}%".format(int(p.get_height() * 100)),  # Format pour la hauteur/accuracy
            (p.get_x() + p.get_width() / 2.0, p.get_height()),
            ha="center",
            va="center",
            xytext=(0, 5),
            textcoords="offset points",
            fontsize=5,
        )

plt.legend(loc="upper right", fontsize=7)
plt.title(
    "Accuracy per model and context", fontsize=16, fontweight="bold"
)  # Ajout d'une police plus marquée pour le titre
plt.xlabel("Dataset", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
sns.despine()  # Retrait des bordures indésirables
plt.tight_layout()
# Set size inches
plt.gcf().set_size_inches(8, h=8 / 1.618)
# Reduce font size
plt.rcParams.update({"font.size": 6})

# Export to latex
path = os.path.join(pwd, "figures", "difficulty_estimation", "accuracy.pgf")
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
plt.savefig(path)

# Display latex
with open(path, "r") as file:
    latex = file.read()
print(latex)
# Out:
# %% Creator: Matplotlib, PGF backend
# %%
# %% To include the figure in your LaTeX document, write
# %%   \input{<filename>.pgf}
# %%
# %% Make sure the required packages are loaded in your preamble
# %%   \usepackage{pgf}
# %%
# %% Also ensure that all the required font packages are loaded; for instance,
# %% the lmodern package is sometimes necessary when using math font.
# %%   \usepackage{lmodern}
# %%
# %% Figures using additional raster images can only be included by \input if
# %% they are in the same directory as the main LaTeX file. For loading figures
# %% from other directories you can use the `import` package
# %%   \usepackage{import}
# %%
# %% and then include the figures with
# %%   \import{<path to file>}{<filename>.pgf}
# %%
# %% Matplotlib used the following preamble
# %%   \def\mathdefault#1{#1}
# %%   \everymath=\expandafter{\the\everymath\displaystyle}
# %%
# %%   \makeatletter\@ifpackageloaded{underscore}{}{\usepackage[strings]{underscore}}\makeatother
# %%
# \begingroup%
# \makeatletter%
# \begin{pgfpicture}%
# \pgfpathrectangle{\pgfpointorigin}{\pgfqpoint{8.000000in}{4.944376in}}%
# \pgfusepath{use as bounding box, clip}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{8.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{8.000000in}{4.944376in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{4.944376in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{4.532345in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{4.532345in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.019727in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{3.635786in}}%
# \pgfpathlineto{\pgfqpoint{1.019727in}{3.635786in}}%
# \pgfpathlineto{\pgfqpoint{1.019727in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.362063in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{4.219592in}}%
# \pgfpathlineto{\pgfqpoint{3.362063in}{4.219592in}}%
# \pgfpathlineto{\pgfqpoint{3.362063in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.704398in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{2.634977in}}%
# \pgfpathlineto{\pgfqpoint{5.704398in}{2.634977in}}%
# \pgfpathlineto{\pgfqpoint{5.704398in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{3.594086in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{3.594086in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{4.344693in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{4.344693in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{2.676678in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{2.676678in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{3.260483in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{3.260483in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{3.719187in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{3.719187in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{2.718378in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{2.718378in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{3.177082in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{3.177082in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{4.011090in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{4.011090in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{2.760078in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{2.760078in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{3.135382in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{3.135382in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{3.969390in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{3.969390in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{3.051981in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{3.051981in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{4.011090in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{4.011090in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{2.551576in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{3.218783in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{3.218783in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{2.051172in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{2.051172in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{2.468176in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{2.468176in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{1.926071in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{1.926071in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{2.259674in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{2.259674in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.893596in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.893596in}{2.343075in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{2.343075in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.235931in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.235931in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{2.009471in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.578266in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.578266in}{2.051172in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{2.051172in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{3.940686in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{1.956661in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.956661in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}ljl}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{4.298997in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.298997in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}sentences}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{6.641332in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.641332in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}french-difficulty}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.298997in,y=0.315424in,,top]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Dataset}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=0.543433in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.0}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{1.425666in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=1.377441in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.2}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{2.259674in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=2.211448in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.4}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{3.093681in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=3.045456in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.6}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{3.927689in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=3.879464in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.8}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.455246in,y=2.562002in,,bottom,rotate=90.000000]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Accuracy}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{4.532345in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{0.591658in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.113421in,y=3.705231in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}73%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.455756in,y=4.289036in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}87%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.798092in,y=2.704422in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}49%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.300808in,y=3.663531in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}72%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.643143in,y=4.414137in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}90%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.985478in,y=2.746122in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}50%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.488194in,y=3.329927in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}64%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.830530in,y=3.788632in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}75%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.172865in,y=2.787822in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}51%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.675581in,y=3.246527in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}62%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.017917in,y=4.080534in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}82%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.360252in,y=2.829523in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}52%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.862968in,y=3.204826in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}61%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.205303in,y=4.038834in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}81%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.547639in,y=2.621021in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.050355in,y=3.121426in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}59%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.392690in,y=4.080534in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}82%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.735026in,y=2.621021in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.237742in,y=2.621021in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.580077in,y=3.288227in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}63%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.922413in,y=2.120616in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}35%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.425129in,y=2.537620in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}45%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.767464in,y=1.995515in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}32%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.109799in,y=2.078916in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.612515in,y=2.329118in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}40%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.954851in,y=2.078916in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.297186in,y=2.078916in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.799902in,y=2.412519in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}42%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.142238in,y=2.078916in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.484573in,y=2.120616in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}35%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.298997in,y=4.615678in,,base]{\color{textcolor}{\rmfamily\fontsize{16.000000}{19.200000}\bfseries\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Accuracy per model and context}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetfillopacity{0.800000}%
# \pgfsetlinewidth{1.003750pt}%
# \definecolor{currentstroke}{rgb}{0.800000,0.800000,0.800000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.800000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.907092in}{3.098859in}}%
# \pgfpathlineto{\pgfqpoint{7.744444in}{3.098859in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{7.763889in}{3.098859in}}{\pgfqpoint{7.763889in}{3.118303in}}%
# \pgfpathlineto{\pgfqpoint{7.763889in}{4.464289in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{7.763889in}{4.483734in}}{\pgfqpoint{7.744444in}{4.483734in}}%
# \pgfpathlineto{\pgfqpoint{5.907092in}{4.483734in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{5.887648in}{4.483734in}}{\pgfqpoint{5.887648in}{4.464289in}}%
# \pgfpathlineto{\pgfqpoint{5.887648in}{3.118303in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{5.887648in}{3.098859in}}{\pgfqpoint{5.907092in}{3.098859in}}%
# \pgfpathlineto{\pgfqpoint{5.907092in}{3.098859in}}%
# \pgfpathclose%
# \pgfusepath{stroke,fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.376789in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.376789in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.444845in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.444845in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.376789in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.376789in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GPT-3.5-turbo-1106}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.241218in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.241218in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.309274in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.309274in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.241218in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.241218in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GPT-3.5-turbo-1106 + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.105648in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.105648in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.173703in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.173703in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.105648in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.105648in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Mistral-7B + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.970077in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.970077in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.038132in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.038132in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.970077in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.970077in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}CamemBERT}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.834506in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.834506in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.902561in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.902561in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.834506in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.834506in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Davinci-002 + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.698935in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.698935in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.766991in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.766991in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.698935in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.698935in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Davinci-002}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.563364in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.563364in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.631420in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.631420in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.563364in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.563364in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Mistral-7B}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.427793in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.427793in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.495849in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.495849in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.427793in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.427793in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GFI}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.292223in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.292223in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.360278in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.360278in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.292223in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.292223in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}ARI}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.156652in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.156652in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.224707in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.224707in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.156652in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.156652in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}FKGL}}%
# \end{pgfscope}%
# \end{pgfpicture}%
# \makeatother%
# \endgroup%
